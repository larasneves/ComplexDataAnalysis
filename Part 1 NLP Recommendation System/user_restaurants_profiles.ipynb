# %%
import pandas as pd
from sklearn.decomposition import LatentDirichletAllocation,TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
from collections import Counter
import numpy as np
from gensim.models.doc2vec import Doc2Vec,TaggedDocument

# %%
reviews = pd.read_csv("yelp_academic_dataset_review.csv")
businesses = pd.read_csv("yelp_academic_dataset_business.csv")

# %%
reviews = reviews.merge(businesses, how='left', on='business_id')
reviews = reviews[(reviews['city'] == 'Philadelphia') & (reviews['categories'].str.contains('Restaurants', na=False))]
reviews.reset_index(drop=True, inplace=True)
reviews = reviews[['review_id', 'user_id', 'business_id', 'stars_x', 'text']]
reviews['liked'] = (reviews['stars_x'] > 3).astype(int)
reviews
# Out:
#                      review_id                 user_id  \
# 0       AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 1       JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A
# 2       8JFGBuHMoiNDyfcxuWNtrA  smOvOajNG0lS4Pq7d8g4JQ
# 3       oyaMhzBSwfGgemSGuZCdwQ  Dd1jQj7S-BFGqRbApFzCFw
# 4       Xs8Z8lmKkosqW5mw_sVAoA  IQsF3Rc6IgCzjVV9DE8KXg
# ...                        ...                     ...
# 687284  Wrt6pZizQzw-ZTKrvMwrGw  ua6QuBe6mar6pDrhHETzJQ
# 687285  X5R98ygOtbhryDiKA-J2qQ  LHWtjTG7e1NzNPYUbUo-9w
# 687286  MVg4YUQeEhCA7Z7RsBJSVg  7-7A0Avj47slLGV7yBFc8w
# 687287  nLjbVsETpqO17RbFcqskkA  am7-gkH_PDz598oTdYSD6A
# 687288  cACxcUY_AIsQKkpDRXuqnw  MCzlzlOw7IGbRAKVjJBPtg
#
#                    business_id  stars_x  \
# 0       kxX2SOes4o-D3ZQBkiMRfA      5.0
# 1       04UD14gamNjLY0IDYVhHJg      1.0
# 2       RZtGWDLCAtuipwaZ-UfjmQ      4.0
# 3       YtSqYv1Q_pOltsVPSx54SA      5.0
# 4       eFvzHawVJofxSnD7TgbZtg      5.0
# ...                        ...      ...
# 687284  Bk_1vsPtOtO0bojfQZQIOw      2.0
# 687285  rgeuy1qbw6Z8B6CSVANHIA      5.0
# 687286  ytynqOUb3hjKeJfRj5Tshw      3.0
# 687287  3gVSrS4kffGGZT8oXHsIcw      3.0
# 687288  fcGexL5VH5G2Xw0tRj9uOQ      3.0
#
#                                                      text  liked
# 0       Wow!  Yummy, different,  delicious.   Our favo...      1
# 1       I am a long term frequent customer of this est...      0
# 2       Good food--loved the gnocchi with marinara\nth...      1
# 3       Tremendous service (Big shout out to Douglas) ...      1
# 4       My absolute favorite cafe in the city. Their b...      1
# ...                                                   ...    ...
# 687284  Ok, I have to say, after living on this block ...      0
# 687285  I've been to the other Federal Donuts location...      1
# 687286  I was so excited about all the food I saw, but...      0
# 687287  *Later Yelp* I've only been here once, but I l...      0
# 687288  This is a good pizza option - they deliver thr...      0
#
# [687289 rows x 6 columns]

# %%
sample = reviews.sample(10000).reset_index(drop=True)
sample
# Out:
#                    review_id                 user_id             business_id  \
# 0     z_NsFhbdJo7RYKnZT5WWAw  hZHRtmXk5JhSszriw3jnkg  lGwmPQcKEGPIEWKGSoM1kw
# 1     bVVDKOEVdDa1HgD-kfaxoA  gejdn9yFiMmvBQYJZ5V7iQ  RQAF6a0akMiot5lZZnMNNw
# 2     PHd1EEmTSHNK8pl8XTBxqw  7QhdBy475-dT4NQUu701Ng  DsKzHnkLKnxZTVsFpts4oA
# 3     cnbhYcx0RC_9utV1VXmvrQ  ZtEI69EQuYsxKKsmqqGogg  PDGyduDCysMP5L__5BnYJA
# 4     FLHizI8QtACw80kac35UGg  gC9xulH0GzQAAzWh-OH0Pg  8-1vYscR7TNGF7LcJeNZBQ
# ...                      ...                     ...                     ...
# 9995  _Co9V_xydJj1YeAz0pO1Rg  zPPyxgbjhcy2tHo3F1jMXw  sV6up2rehuTegmfo3uYUtA
# 9996  MOUnCwuGyB5Aqz4btFD0WA  4CLAGiVV7EyRGhntHWazQA  U2y7fsqDgxAXskoJNVxbwg
# 9997  l-zv0sX202_Amq8EMAD1VA  u766nLu7-4ptpYTPdlGbnA  rgeuy1qbw6Z8B6CSVANHIA
# 9998  WW3yDjijXivr9R37LqQS3Q  ITpldUH1k90kuxJfccW4SA  kzy0Kf7z1ucbL2sVbfAFsg
# 9999  tbB1ztrX1HerZdr3AO3cbA  YE5hSKqAdPhVC7qQ_8NW-g  b0YICdDCw8Ck6hJPc1Z5HQ
#
#       stars_x                                               text  liked
# 0         5.0  I like theirs food.the special blend sauce is ...      1
# 1         5.0  The best cheesesteaks plain and simple. If you...      1
# 2         1.0  For a restaurant/tavern that's attached to a n...      0
# 3         5.0  I was so relieved to see they were reopening "...      1
# 4         5.0  The fresh Grill Chicken BBQ Pizza is to die fo...      1
# ...       ...                                                ...    ...
# 9995      3.0  Nothing to write home about. Service was great...      0
# 9996      5.0  I love this place!! I come here once a week- p...      1
# 9997      5.0  This place was attached to our hotel so we sto...      1
# 9998      3.0  My husband I went here for the second time rec...      0
# 9999      5.0  Surprisingly, tonight was my first night visit...      1
#
# [10000 rows x 6 columns]

# %%
# Normalization
corpus = []
ps = PorterStemmer()
sw = set(stopwords.words('english'))
for i in range(0, reviews['text'].size):
    # get review and remove non alpha chars
    review = re.sub('[^a-zA-Z]', ' ', reviews['text'][i])
    # to lower-case
    review = review.lower()
    # split into tokens, apply stemming and remove stop words
    review = ' '.join([w for w in review.split() if w not in sw])
    corpus.append(review)

corpus
# Out:
# ['wow yummy different delicious favorite lamb curry korma different kinds naan let outside deter almost changed minds go try something new glad',
#  'long term frequent customer establishment went order take apps told busy really place maybe half full best dick reach ass yes go fuck frequent customer great tipper glad kanella opened never going back dmitris',
#  'good food loved gnocchi marinara baked eggplant appetizer good service slow despite go back food good',
#  'tremendous service big shout douglas complemented delicious food pretty expensive establishment avg main course definitely backs atmosphere comparable top tier restaurants across country',
#  'absolute favorite cafe city black white latte probably best ever sweet right amount foam soups always really good even non soup people lot space work noise level perfect music perfect level always enjoy patrons bring dogs keep giving business long',
#  'boyfriend tried deli first time today turkey avocado bacon panini ha buffalo chicken wrap definitely returning wait food long always appreciated lunch hour much choose salads soup macaroni sandwiches hot food love deli many options choose',
#  'reason give restaurant star rating one single pretentious waiter night guest hotel palomar location restaurant obvious plus first night stay met coworker restaurant cocktail arrived host staff busy available walked restaurant busy looked small table next bar proceeded take seat waiter came quickly asked could seat sitting told cocktails stumbled reply irritated convinced tone told guess would fine basically kept walking mid sentence guest brushed started conversation looking drink menu make long story short distant got bothered vibe came bill asked could split due company transaction policies would thought asked inconceivable task basically spent rest night elevator ride room shock rudeness experienced although situation left bad taste mouth night decided avoid restaurant decided grab another cocktail give place one try looking around ensuring last nights waiter shift walked bar started looking menu instantly bartender greeted us pleasant small talk made us feel welcome asked day recommended cocktails completely genuine person guy think name ben absolute star gave us lessons whiskey described make classic cocktails invested experience exactly bartender star establishment actually exceeds kind funny friendly completely redeemed restaurant bar terrible experience night also ordered room service last night restaurant amazing bacon wrapped dates chocolate cake die great restaurant amazing bartender bad one bad egg could spoiled experience',
#  'scale one things awesome place bomb drawn promise duckfat frenchfries took boy birthday put name drink around corner waited given seats bar minutes waited keith bartender congenial knowledgeable whiskeys around cool guy started cape may salts two one boy tater tots made happy dinner got kentucky fried quail stellar though succotash exciting wanted boy got fois gras burger incredible worth every penny duckfat fries pretty yummy even best part meal could done without cheese sauce side deterred look forward coming back everyone know',
#  'fiance birthday decided wanted good laid back thai restaurant dinner yelp steered us jasmine rice direction definitely good decision wanted summer rolls menu apparently available summer settled pan fried dumplings flavor good think order got green curry fried rice duck chicken pad thai dishes great duck stole show tastiest duck ever pad thai bit sweet us think try different noodle dish return still good especially chili sauce mixed service good people issues one table rushing get show kimmel center waited quite meal going late another person got take missing one items owner realized called walked dish house nice overall good quality thai would definitely go back',
#  'brother came visit wanted pick six pack good beers night ended staying playing nintendo super smash brothers owner said donated fellow patrons great place good food genuinely nice people staple northeast',
#  'go menu coconut soup pad thai protein tried menu actually really like coconut soup used enough amount coconut milk soup really creamy powering herb used americanized thai cuisine prefer less herb dish except cilantro pat thai great liked amount peanut used noodle chewy perfect sweet gave generous amount chicken white meat dry happy meal',
#  'go spot saturday night real bummed lucys closed pleasantly surprised bar across street food better expected always get wings fries careful wtf sauce though sometimes takes real long time get bartenders attention place usually packed lucky always sunny crew pop',
#  'cannolis awesome freshly filled ordered filling phenomenal sweet perfect like cannoli think like cannoli definitely get one termini bros',
#  'couple friends stopped late night milkshakes found ice cream well got ice cream fully taking advantage name implies maybe next time milkshakes coffee chocolate black white malt pretty good definitely satisfied ice cream craving thought coffee milkshake could thicker goes chocolate black white plenty thick probably best three unfortunately order one settled creamy coffee sample ice cream flavors setting milkshake tried pumpkin pie amazing know get maybe milkshake way go',
#  'husband took mother th birthday say enough treatment received great table view delicious compliments chef extra dishes beautifully decorated cake plate warm attentive servers much expected even special occasion us wonderfully memorable experience',
#  'number dog friendly hotels city know expect usually motel like one heart city walked tentatively hotel lobby labrador golden mix easy hide got front desk register still feeling uneasy although bf assured dog friendly hotel reception nice immediately putting us ease checked attendant asked bentley could treats fullly enjoyed reception person also asked would like welcome kit bentley holy moly course dog dishes mat treats etc blown away plus guests hotel stopped compliment pet queen bentley room top floor awesome even went walk car attendants greeted name impressed service decided come back extra night thank loews didnt realize hotel could dog friendly especially big dog',
#  'trying ramen places crazy variety selections stellar broth excited ramen got cheu maybe matter taste personally fan thick noodles extremely salty broth service great nice selection beers friend went loved many times honestly sorry bigger fan hope others try might oddball one',
#  'looks like second red kings restaurant chinatown disappoint since place opened yesterday exactly sure replacing red kings street second helping spicy szechuan food ordered takeout picked dan dan noodles shredded pork garlic sauce dish spice level dishes perfect extremely mouth burning delicious flavors sweet earthy fresh portions generous make great leftovers us wait try dishes come back sit dinner also karaoke rooms upstairs plus byob',
#  'good food reasonably priced nice staff ideal eating since going fast food approach vegan food makes lot sense know buffalo bella dish push hardest money cheesesteak way go pro tip get sweet potato fries',
#  'oh chickie pete perfect place watch sports indulge doubt best food ever get seat grab beer mussels red crab fries way thoroughly enjoy place game time stadiums favs crab fries mussels red white overloaded garlic always take spicy pull peel shrimp steamers mood right blue crabs lot work tasty place also makes getting dirty food easy sinks rinse mess hands done good touch sum chickie pete philadelphia institution always good time strongly suggest going least enjoy experience please note make sure remember two things coming major sporting events never get table deal ton drunk people absolutely one people get annoying unless right frame mind',
#  'dine gets stars disappointing service venue falls short food ok take maybe place would get stars ordered lamb kebab tasted ok plain sauces lettuce anything meat',
#  'cannot even believe someone gave place one star scoop best cannoli city termini near good isgro far hyped quality potito go cannoli even think going anywhere else every xmas eve rest days stood line isgros two hours year tirimisu walked right potito picked bambino cannoli stuffed cannoli good sounds trust',
#  'giving joint stars earned definitely star material work kinks granted opened errors experienced work area several times probably get worked willing make corrections accommodations mess food really good unlike fellow yelp ers would say ther pizza strong suit kinds greasy sure use mozzarella tastes like cut something cheaper however far quaker chicken version delicious make chicken steaks chunky chicken like much shredded version could season chicken cheese melted perfectly veggies fresh fries crisp flavorful even need ketchup always eat ketchup fries onion rings little greasy tasty crisp onions stayed breading slide bit hate spanakopita mine little cooked flavors really good baklava good signature salad veggies use fresh make break salad balsamic great turkey greek burger one best turkey burgers ever patty moist flavorful top must homemade tzatziki could eat bowl stuff burger romaine instead advertised arugula fresh mind much also asked feta get sauce made forget overall place great provided stray high quality standard setting keep going back',
#  'picked takeout village whiskey review actual restaurant whiskey burger pricy amazing ok greasier burger super tender bacon awesome pretty big get past price highly recommend duck fat fries also rich delicious',
#  'place gem attractive space great location near broad street line plenty street parking byob twice enjoyed every dish highlights chaats beef short ribs lamb vindaloo beet salad breads pickles chai got chocolate cake table share time everyone loved get takeout beer corner bar back',
#  'airport grab go restaurants earl decent job variety sandwich options including turkey tuna even hawaiian today could smell roast beef got one yum good portion sliced beef beyond medium cooked cheddar cheese yummy horseradish sauce nope get lettuce tomatoes perfect way since right security station top gates right near delta skyclub easy get eat gate board',
#  'share main issue want share reason give stars awesome server latoya thoughtful engaging black bean burger dry sweet potato fries good today lunch group colleagues disturbing thing happened noticed manager green sweater lingering around entrance two cop cars lights flashing pulled officers rushed walked table next us manager pointing one officer proceeded pull handcuffs tell guy delivering food put food table hands behind back escorted near front door sit moment taking outside freezing cold jacket stood minutes cops came restaurant entire thing poorly handled disturbing unsettling customers staff cops walk back away customers deal managers disappeared available talk customers let alone apologize acknowledge people unsettled one needs know arrest happened needed care customers staff handled ok',
#  'wee bit pricey portions serve come beck gator gumbo jambalaya whole thing savory spices right overly spicy salty well great meal gator sausage form chopped gumbo visit order pasta chicken alfredo year old son alright whole pasta tasted bit dry something get twice verdict gator gumbo end story',
#  'love sweet spiral plain pies franzones go wrong plain tried white pizza onions addition pleasant surprise onions great addition pizza franzone bridgeport one grew',
#  'went friend incredible experience laurel hoping slightly less bulgy pricepoint oh worth itv kind place dream beautiful small room dimly lit see opposed places want see everything everything room beautiful including lot staff im trying give full picture first thing hit table bar case three dollar beef fat biscuit best thing ive eaten city year verbally communicated message chef nick elmi graced us presence dining room laurel went eat many things try name stars foie apricot miso pork cheeks insanely good vegetables trout pumpernickel soldiers one best cocktails ive damn long time ouroboros playing around cold smoking things bar menu honestly place terrific meant write review sooner hey better late never think im getting hungry maybe ill head east passyunk best city offer',
#  'absolutely wonderful food service go lunch dinner boyfriend least every two weeks prices much reasonable weekends get pretty packed may wait little bit never issue us always get indian pancake hainanese chicken curry chicken dishes delicious well never get tired',
#  'recently pre fixe meal enjoyed combination tastes plate chicken moist veggies tasty little greasy overall great meal also use take delivery always enjoyed way package food plastic containers use look worn recycle hate take places use much boxes cups card board extremely eco unfriendly food never spectacular good standby always come away enjoying prices seem little steep restaurant atmosphere contemporary service always splendid food dependable',
#  'last night tried get oldest italian restaurant south philly thankfully fit us son said lets try angelina walked around corner small italian restaurant immediatly felt home angelina cooking front resaurant husband servicing us started eggplant roasted pepper appetizer one bite hooked ordered veal osso bocca carbonara lasagna everything absolutly delish wait go back',
#  'great food great view try lobster mac cheese',
#  'good place order late muchies whatever reason',
#  'really like franzone owner typically around super friendly seems really care product big fan sweet sauce also decent cheesesteak fries etc honestly may closer always really pleasant experience going boosts rating',
#  'great selection whiskey bourbon suit anyone taste burgers fried egg soo good probably one best burgers ever duck fries must come cute atmosphere although went party tad awkward way seating made difficult conversation everyone table overall nice place go going back',
#  'ten ten best food lighting noise environment staff',
#  'got gyro platter lunch dry uninspired nothing like deconstructed gyro worst came vegetables looked like poop tasted way better places fairmount lunch serve poop either',
#  'although countless little mexican places washington avenue never get sick always look forward trying new kid block time el sabor poblano federal could look less special tried liked fish tacos menu picked fried battered version though tortilla chip covered fish could awesome instantly impressed opened one three found el sabor puts entire filet fish taco flakey meat fishy taste tacos came american toppings lettuce tomato cheese bet could gotten cilantro onion asked sole staff member place seemed happy accommodate us well ones dining another taco filling option comes traditional toppings super crispy chorizo detectable gristle something often come across little places unassuming looks particular south philly mexican place worth stopping',
#  'hate harsh dang limited selection terminal f finally decided go tony luke looking forward trying philly cheese steak philly unraveled sandwich surprise sandwich got look nothing like picture overhead display sandwich part got even meat know taste like eat dog food sure paid',
#  'new han dynasty took spot old mid atlantic restaurant unchanging menu like han dynasty lot one olde city even give maybe biased love service always nice came check make small conversation heard peanut allergy even though peanuts dishes ordered think han sister han dynasty times month number times note though different branches different specialties heard dan dan mian olde city best one uc good know since peanuts overall think okay food wise still spicy enough branch like layout atmosphere lot next go lunch ask lunch portions smaller dinner portions half menu price great lunch place alone group',
#  'small hole wall african section woodland avenue though might look like much good food coming kitchen representing senegal west africa enjoyed national dish senegal thiboudienne although note version without usual tomato sauce also took home jollof rice often called mother dish jambalaya hightop tables inside dining order food go either way service friendly',
#  'awesome food great place split bunch delicious spicy ultra flavorful dishes large group chinese restaurant lot people know good reason single bad dish always crowd pleaser',
#  'beautiful clean shop knock socks everything homemade breakfast tarts chicken pot pies sweets looked well beyond beautiful delish felt items tad pricey considering sizes smaller size know premium quality costs great place locals worth trip traveling center city etc found counter staff friendly engaging back certainly recommend',
#  'best soon dubu city place tucked away walk like stepped korean home welcoming warm inviting vegetarian friendly soft tofu stewed put dol sot pots every stew feels like custom made select beef seafood mixed meats seafood beef mushroom plain adjust spice needed always get extra hot hot temperature beat rice also comes dol sot great leave burns rice nice crispy shell drool thinking place makes mouth salivate tofu also offer korean bbq meats cooked back soup stew items love place',
#  'second walk door greeted adorable woman counter seems come week know name lucky since visits bit sporadic recent discovery vegetarian breakfast sandwiches served day particularly enjoy veg sausage w havarti everything bagel could actually go one right also veggie club sandwich half enjoyed chicken cheesesteak hoagie chicken salad croissant everything always taste fresh priced really well think favorite bagel sandwich mentioned cheaper wawa people deli super helpful offering menus read one wall make great suggestions accommodations needs want forget grab really great snack amazing chocolate bars incredible drink case tons chip varieties addictive hi chew candies every flavor know back like fast delicious attentive service',
#  'stopped brunch expecting food delicious meat hash amazing turkey sandwich bagel salmon employees friendly accommodating little pricey well worth visit area',
#  'second stop center city restaurant week r l dinner th floor two liberty place fancy cool restaurant lounge get bird eye view city group us went dinner together day meetings get one tables facing windows still great views sunset city night multiple choices three courses chose start crisp peas ham garlic risotto balls main course butcher filet braised short rib steuben bean chili potato farm veg slaw basil quite heavy since also meat chili well dazzling dessert finish milk chocolate hazelnut pudding served salted caramel coffee melt chocolate candied almonds side bottle wine table well food great waiter awesome making sure warn risotto came ball form rather bowl instance classy experience',
#  'moved chicago philadelphia year ago everybody raves restaurants yet find many deserve five stars even four best restaurant eaten philadelphia tahini bread arrived table thought hum plain hungry must put crack tahini wanted lap bowl like uncouth dog bread excellent love menu many organic meat choices often order organic beef shishkabob superb meat done perfectly onions nearly caramelized quite still substantive crunch purslane salad tasted like eating plant middle garden often dream salad dream one husband chicken dish black eyed peas green peas fantastic rice begin describe flavoring beyond culinary vocabulary asked spices use addition traditional zatar use blend spices even need know long keep coming back ordering full ate dessert none less usually diner good feeling desserts would needed find pistachio creme brulee could come top indeed pure pistachio heaven super light yet rich custard heaven heaven service superb squeezed us last minute friday night reservation caveat would need get dinner hour minutes order accommodate reservation made prior us given time constraints never made us feel rushed timed meal perfectly husband left go restroom waiter picked napkin refolded nicely table care napkin placement middle meal really sign waitstaff incredibly attentive extremely well trained eating plan philly might skip eating everywhere time frequent expensive though appropriately priced restaurant kudos chef',
#  'served frozen pizza skunked beer nuff said',
#  'walked restaurant reservations many open tables asked manager window table responded reserved two hours later left still many open tables next windows overall food good filet salmon bottle wine recommended told prior ordering last bottle',
#  'super lunch option watch yoga mats miss meat lunch strange since hipcity opened thing meat eater mean like last meal earth would burger maybe fajita wrap good everything menu yet everything great buffalo bella crispy hipcity ranch amazing sandwich alternatives especially paired green lemonade groothie also delicious stand get afternoon want spend bucks okay suffice say food great staff also friendly get busy someone come along line take orders congestion get bad register issue hipcity times nearly impossible figure stand waiting order waiting food people kind convene everywhere get awkward line door small space hard rectify see line door tend walk long wait really efficient difficult navigate interior',
#  'place posted hours include pm closing time walked soon got counter guy said kitchen closed grill fryers etc covered first kitchen closed door restaurant unlocked secondly could see case walked say pm ridiculous',
#  'food good cafe extremely dirty probably return unless clean place',
#  'need know everything taste great well least practically tried everything breakfast come conclusion spot breakfast one gripe though monte cisto worth price way priced know truffle oil used reason damn expensive one egg one piece toast sauce ever order worth unless drop price everything else worth taste great jebbs open face huevos rancheros favs enjoy oh coffee addicting also reservations get early go min u think u may hungry',
#  'best prepared sushi inthe city longshot quick mean quick cheap sushi long menu mixx great',
#  'huge fan gennaro got thin crust sweet rich tomato sauce along w fresh mozzarella cheese also meatballs excellent say enough much love also decor vintage adorable yet disappointed gennaro',
#  'great atmosphere service friendly prices reasonable however found food bit bland bad bland husband starving long drive philly filled spot overly enjoyable likely back',
#  'fuck yes meat bourbon libations salad round things aka make feel better ingesting aforementioned two items took early birthday date disappointed neither food company medium rare plain burger see worth fuss cheese bacon dressing etc disguise quality meat course bread either since gluten free burger great perfectly cooked seasoned though felt like bit freak sitting bar eating burger knife fork like come back try fancypants burger since extras look pretty tasty salad frills perfect amount dressing bartender cum waiter super attentive cloyingly made delicious sazeracs accompany repast',
#  'one best burgers philly low key joint tables kitchen dining room let modest face fool place rocks menu creative fully customizable burgers cooked flattop perfectly seared juicy slightly charred fries hand cut fried fresh perfectly crispy salty could ask burger place pro tip download spot app rewards program good coupons aka free fries',
#  'trying twice unsuccessfully get early enough get meal within minutes finally able break away work th line heard food truck nazi best town found gus falafel nazi called lived reputation turn came approached cart tenuously want blow asking many questions immediately recognized new customer told fresh ingredients uses chicken cooked coal tender inside perfectly cooked outside falafel delicious grapes homemade pasta went along enough food people well worth wait',
#  'went restaurant running philadelphia marathon large group us including kids ages parents grandparents place clean looks fairly new least newly decorated service excellent friendly food good parents everything spicy side great kids grandparents lighting dim issue grandparents reading menu veggie wings great cactus sweet potato burritos guacamole good although spicy chips little much offer pitchers margaritas great large group',
#  'looking forward new coffee spot dont menu first im coffee connoisseur little thrown kept simple asked iced tea give hot tea w cup ice v artsy crowd great people watching studying little loud headphones enough block noise stuck listening watever chose preference servers really nice kept cleaning tables quite often wasnt bad experience one keep coming back either',
#  'went show seeing university city area across street th street station street drexel university able get street parking blocks street always plus service sufficient dinner tried mac cheese appetizer right amount breadcrumbs served hot average taste also tried cheeseteak egg rolls decent lot meat bites egg roll merely fried dough without getting cheese meat served ketchup special mustard horseradish bit kick must say neat thing philadelphia pub menu main entrees chicken pot pie vegetables plentiful chicken white meat though much crust somewhat flaky section pot pie crust seem like cooked way dessert portion sizes huge bread pudding average taste served scoop vanilla ice cream brownie served ala mode vanilla ice cream well brownie definitely dry lacking taste though consider brownie snob maybe overly picky',
#  'good thing weeks cool experience copabanana writing review might pretty anyhow came university city restaurant week never return sat outside kids playing football right near tables loud moved side restaurant still outside kids made way us continued playing couldnt get away went table inside food terrible steak fatty overcooked mashed potatoes werent fresh waitress thing good place agreed steak took back came back chicken asked like biting rubber bands disaster never return star waitress',
#  'write order coming couple times place terrible tried hoagies greasy got nauseous eating yesterday accidently ordered instead angelinos got buffalo chicken sandwhich covered blu cheese greasy sauce disgusting food terribly greasy seasoned much back little use freasher ingredients much better ill also add desserts suck taste bland waste money sodas usually expired flat hate everything place',
#  'loves seitan keep going el camino seitan wings seitan nachos good unfortunately service extremely slow one occasion took long get seitan nachos give house friends done eating ready leave getting food rest food el camino thing tried would fried pickles say impressed love pickles fried things good coating grainy like taste seitan good keeps coming back margaritas pretty good',
#  'deducted one star service great waiter friendly first question soup salad wanted order appetizer lunch special assumed lunch seaweed salad really good shiomay small good sashimi fresh banzai roll great unique raw salmon white fish avocado fish egg wrapped cucumber sweet sauce perfect looking rice roll salad dressing like carrot pur e',
#  'honestly know place existed friend suggested brunch weekend believe live four blocks away ordered honeybee crepe almond croissant one typically bring leftovers home food delicious nothing left take much surprise friends small seating area downstairs window seating first floor recommend getting earlier side group want sit also recommend smaller groups definitely going back',
#  'long hiatus reviewing awaken mouth yelp hibernation tummies grumbles insatiable hunger cacophonous symphony flavor indian food like familiar pattern go back mohammad butt main man marsala whats whispers longer cooks best taste asia gone never return sort falling need score one final hit life ceases meaning existential murmurings dog mind cheeze wiz done round falls chamber prepare end pull trigger steps zaika zaika meaning art taste stays name place paneer cheese made fresh house resulting cheese silky texture especially contrast prepackaged rubbery bone white lego blocks small indo pak places purchase indian grocers attempts reduce prep times zaika shortcuts taken chef takes extra steps needed ensure dish comes together whole example chicken makhani uses smokey tandoori chicken never seen done certainly aids chicken cut though rich buttery tomato sauce elevates dish whole even entr es like dall fray palak paneer much flavor leave missing animal protein least choose go vegetarian route zaika appetizers like veggie samosa aloo tikki spiced potato patties generally large peppery well spiced latter remind something mother would make though must warn others avoid items occasionally pop specials like potato stuffed chili peppers unless iron stomach gluten punishment peppers spicy deveined even seeded find fish pakora far fishy become rather taken zaikia even simply things naan good right elasticity bread much give yet soft nothing elaborate properly risen light texture egg yeast flavor complaint lacked signature faint sweetness naan hey use mostly mopping good stuff plate anyway sweetness gets lost mix mind menu nearly different items numbered order making take phone orders convenient eliminate fears anyone language barrier problem furthermore short descriptions dish something ethnic places like though items like lassie frothy yogurt drink appear menu offered salty sweet mango verities head chef speaks english quite well easy deal want inquire want setup large orders already noticed parties negotiating catering ramadan anxiously awaited order bottom line mohammad butt expanded menu created best taste asia taken halal meat approach good things come good things p zaika right behind nifty fifties grant ave set dessert want milkshake however would suggest getting ras malai available riccotta cheese dumplings flouting soaked sweetened thickened milk delicately flavored cardamom amount rose water garnished pistachios ungodly good',
#  'ick sums experience dinardo one word dinardo gave ick vibe minute set foot door though greeted friendly hostess place looked like run diner interior clean charming would fine lot times run places best authentic food case dinardo dinardo get pay prices rather high food quality rather low server hated life made snarky mean comments throughout time though entertaining kind unwelcome unpleasant friend mussels puny unimpressive sauce unimpressive general adjective would use describe given dish party ordered soup extremely salty bland beyond broiled flounder seafood imperial dishes ok best say looking good seafood better byob little fish audrey claire anywhere dinardo understand place still business honest',
#  'friend came around pm monday happened default restaurants main street closed sat bar got drinking drinks ordered pulled pork tacos friend burrito bad stellar standard place drink eat mexican food got college feel even middle day keep mind thing',
#  'fast fresh carne good guacamole wish ability customize taco toppings tortilla chips thick dulche de leche soft serve ice cream amazingly delicious wish seating wish table clean ups timely thorough',
#  'coming place years even though live colorado come back every time philadelphia work often tried many items menu many great portions generous prices low go item indian mee goreng eat every day week could good maybe one day get recipe manager actually days co',
#  'came lunch fiancee friend found small table window great varied wine selection got bubbly fiancee got italian orange soda got lamb sausage potato chips crab stuffed peppers snacks got mozzarella prosciutto bacon bits sandwich delicious savory light healthy service prompt polite rustic intimate cozy wine lounge atmosphere low medium noise level bathroom door lock handle kind confusing use first would definitely recommend lunch',
#  'place game changer neighborhood got take tonight food absolutely delicious really stoked moved newly smitted southern latin food family owns also seem sweet think place exactly neighborhood needed',
#  'twice first nightcap bar drinks really good stuff tried lemon hummus pita best hummus ive ever next morning came brunch pretty much terrible first took us minutes get food brunch came cold found hair manager comp check though overall bar great would skip breakfast disappointment kimpton restaurant',
#  'yes little pricey darned near worth certainly seem priority get us menus service pretty point bread good ordered chopped salad crab cake hub got crab cake sandwich fries water drink appetizers walked tip food came quickly food great salad eater crab cake quality fries good another drawback sit bar area bc table size chair plates much p used bank card noticed charged significantly agreed called restaurant manager said banking glitch correct money comes account better',
#  'sort sushi snob going honest literally worst sushi ive ever warm warm tempura also paid side salad literally iceberg lettuce nope spring mix romaine iceberg slivers carrots even purple cabbage literally iceberg puzzled angry smirk whisper well played friend well played never back check mate',
#  'partner split vegetarian platter left stuffed delicious food kind attentive staff help make decisions ordering certainly take advantage definitely back',
#  'place numerous occasions never disappointed friend traveling puerto rico mother law wanted tamales accommodating gave us free samples offer cook pack us great place friendly staff',
#  'stars chickie pete friendly sports bar particularly women lots seating sunday games appreciate sound booth sky means admittedly bad music played commercials along special themes eagles fans place seems smoke free impressed famous crab fries crinkled lightly fried seasoned garlic chili pepper salt something congealed cheese sauce detracts entire experience also prefer fries piping hot however towers beer available complete taps pleasantly tacky loads space booming sound cute servers rowdy fans chickie pete perfect place catch game',
#  'love food big portions interesting ever changing menue issues seating cramped loud conversation coffe good sabrina latkas always perfect bacon best ahve philly',
#  'wow vegetarian health food nut except random diet binges place awesome co worker talked trying one day going getting something putting front created monster may order every day sure think delicious salads every time go greeted smile tons people waiting food well good company',
#  'nothing extraordinary want simple chinese takeout best place around food seems less greasy sometimes find people super nice',
#  'amazing brick oven pizza joint gets better every time go last time went got rotolo prosciutto pizza rotolo dough wrapped around mortadella ricotta cheese topped pistachios oil good order every time size bun cost pizza amazing prosciutto incredibly tasty dough divine service always great beer selection good definitely one best pizza places philly',
#  'great spot pho broth good ordered small filling would definitely come back philly',
#  'went dinner opening day happy great atmosphere lovely staff food fleek green tea pho phree satisfying summer rolls spicy peanut sauce delish pho phonomenal definitely making one regular hot spotz eat way fairmount',
#  'second visit even better first loved butternut squash goat cheese rangoons delightfully filling mushroom yakisoba amazing flavor smoky meaty feel though meatless came coconut curry ramen heaven bowl complaint wait seating way hang bar without constantly feeling servers way breeze deliciousness bowls plates worth wait heading theater plus food comes quickly made curtain barely really happy tummies',
#  'indian food type person place lives hype go let hassan make something try overwhelm different options make sure get chaat lassi two really complement one another',
#  'really disappointed marathon spruce excellent service drinks food thought would transfer location sum server extremely energetic good way like frantic energy enjoy drinks dinner friend visiting aka looking spend money aka get larger tip let us stay longer rushed server brought boxes food still eating without asking wanted minutes later physically put food boxes tableside mumbling something like like food sitting table even want take home next said another friend join another round two drinks told us stay booth needed go bar point blank asked kicking us booth said yes energetically one waiting tables numerous open tables booths around restaurant felt extremely uncomfortable wanted leave immediately friend joined happened server came ask wanted drink seemed surprised told going leave literally told us sit table longer left worked restaurants long time pretty easy please comes restaurant service pleased visit another note food great',
#  'walked place decided check great beer burger place made even better knowing many things organic order menu create burger also rotating beers specials nice atmosphere staff burgers come anything order sides want fries also sandwiches salads want burger vegetarian friendly',
#  'generally support independent restaurants chain places still buy overpriced center city phila hype place actually roomier south philly closets usually take mother law birthday prices jaw dropping quite different online menu food portions ok dessert something different average places bus help bit sync waiter asking us done plates waiter telling us desserts philly standard bathroom bit small accomodate size place',
#  'wawa like beacon cold dark world grew around sheetz locations admit prefer wawa sandwiches really good typical snacks drinks would expect convenience store particular location quite friendly one go near office whatever still walk snacking requirements',
#  'recall day went memorial resturant experience greeted incredibly nice cashier hard decision ordered devils delight girl giggled course confused explained dev delight named idea burger calling devils delight bit funny friends call devil dev hard believe nice girl could aquire nickname cute took thorough medium burger truffle fires wait long even ate burger smell self mouth watering burger cooked perfection burger amazing burger standard beef foundation mozzarella cheese tomato basil portobello mushroom great idea burger mushroom lover side delicious truffle fries perfect excellent quality service bit expensive worth every penny question return customer',
#  'trying find decent place dinner tonight moderately health conscious self came across place figuring wanted put bison burger cart online order realized would two mile round trip excursion job defeated started search elsewhere could get burger mind came back hours later submit order hiked came kitchen walked grabbed burger continued way back work g absolutely love place quite task try find healthy places fit diet dream come true thank',
#  'service good mesquite wings good best share save greedy like try go back work downside weak lemonade weakest ever',
#  'chef kevin sbraga knows fried chicken first exposure succulent birds hot chicken fat ham lo behold lavender honey fried chicken tops spicy cousin chicken brined buttermilk dredged seasoned flour sits ten minutes coated second round flour dropped fryer chicken breast wing thigh drumstick drizzled lavender honey sprinkled salt ground pink peppercorns comes buttermilk biscuit whipped honey thyme butter red bliss potato salad best fried chicken eaten long time crunchy crispy coating outside juicy moist inside sweet honey glaze truly outstanding finger lickin good biscuit awesome would definitely order dish got salty delicious fried smelts chili pepper aioli appetizer friend chris w got filet mignon butter poached king crab surf turf dessert slice salted pecan pie ice cream sundae every dish juniper commons top notch chef sbraga',
#  'really wanted like casselli cards maybe caught bad night really enjoy much visit waiter unpleasant banging plates glasses table delivered maybe bad day still would expected better mixed experiences food mine friends ok wife baked ravioli would use hockey team use pucks really overdone woefully overdone worst part table next opera singer guy singing extremely loudly nigh impossible maintain conversation especially coupled close table next us attempts speak opera guy part wants give another chance since hate writing bad reviews part annoyed waiter attitude probably go back many good italian restaurants worth visiting opportunity cost returning casselli seems high upside somewhat convenient parking lot behind restaurant near shawmont school note cash',
#  'came see son band last frontier staff food top notch porkbelly fish nachos awesome great selection whisky great sound system band',
#  'came st birthday dinner family great experience food drinks die extremely overpriced even though quality food good still think worth paid recommend getting lobster mac cheese appetizer probably best mac cheese ever eaten end meal gave us small complimentary desserts even though ordered bunch desserts top meal great time definitely overpriced',
#  'like place lot stopped friends drinks eager return food finally weekend ambience nice somehow ideal fun date well beer sports crowd love open kitchen great beer selection definitely return rosemary fries fianc e return good house burger',
#  'originally little group headed franklin fountain line around block capofitto steps away line bonus cheaper better dessert treat popped gelato would love come back pizza looked smelled really good gelato amazing capogiro gelato always highly recommend chocolat scurio pera combo perfect',
#  'highly recommend place first chef tasting exquisite courses truly delicious wine amazing philly highly recommend vetri',
#  'want best burger philly right place come bread fresh meat nothing juicy service amiable price descent affordable everybody',
#  'decent falafel wrap exactly cheap cave like sitting area cold uninviting better choices manayunk',
#  'great spot coming years top steaks city nothing changed even name change try chicken cheesesteak something different',
#  'pina easily one mroe underated places eat roxborough great stromboli huge thier sicilian pie best every sandwiches pizza ok stopped ina two occassions sit dinner came away stisfied full ordered chicken park huge chickem covered cheese sauce excellent',
#  'went boyfriend loved old school feeling floors twice time great food amazing got veal since recommended well clams casino mussles pasta oil garlic home made garlic bread staff nice helpful went recently area new dish gnocchi gorgonzola sauce delicious new favorite dish place must eat',
#  'went friends place reunion dinner seen eachother since elementary school got reacquainted facebook pretty special dinner restaurant swanky prices show think food worth price although party thought expensive ordered lobster bake delicious fantastic alot seafood adequate also ordered neopolitan old fashion made perfectly friends ordered fritters carpaccio crab cake fries plus shots tequila lemonade old fashions bill bad friends expected must say something waiter unfortunately remember name fantastic attentive nice even bought dessert also one friend bday real cool stars service stars food stars ambience stars price satisfied',
#  'first trip susanna foo months old restaurant still hole wall takeout joint owned susanna parents parents taking brother ever since many fond memories susanna fashioning dolls us linen napkins preparing chicken cashew nuts refused eat anything else food always reliable adult find lacking excitement service always impeccable never disappointed overall decor ambience like see susanna improve upon traditional recipes either adding new flavors perhaps returning chinese roots ethnic menu hoping revitalization come love susanna foo much child',
#  'stars really mean white brick walls cool rustic furniture seasoned attractive employees lighting lovely nay perfect probably good blind date service good timely could expensive getting kitchen accommodating first time ever ate around first opened ordered ravioli received pieces another time visited tried substituting salad fries burger server said sorry kitchen er kidding super modification asked burger one bun tomato half piece lettuce two onion rings love like wanted substitute lobster fries needless say first time unable substitute usually really easy please first time ever felt difficult least head head unforgivable',
#  'good drinks food pulled pork fried chicken po boy mac cheese amazing reasonable price great draft list well serves food till',
#  'loew hotel clean looks nice service amazing family wanted stay whole month breakfast fantastic son said looked like future nice rooms nice size parking convenient give loew hotel stars',
#  'pros superb cheeseburger thick evenly cooked almost medium rare nice sauce soft bun tasty complimentary zucchini bread good service good g selection cool ambience downstairs apartment cons expensive per wife waitress seemed disappointed ordered cheeseburgers verified status con review looking forward going back',
#  'might favorite coffee shop city food unbelievable anything ordered fresh delicious enjoyable place cool edgy vibe lots comfy seating great seats outside weather nice definitely worth checking especially want food well',
#  'hype federal donuts made little worried live reputation absolutely vegetarian personally comment donuts coffee however husband obsessed chicken favorite buttermilk ranch donuts pretty amazing paired iced coffee get better staff nicer even busy',
#  'overrated place ok often crust burned maybe pallets sophisticated enough appreciate taste thing enjoyed cauliflower salad fried dough ball dessert delish',
#  'dearest reader please allow hereby confirm rumors village whiskey fact best burger philadelphia note best bartenders wife sat bar waiting friends arrive marveled infinite selection whiskeys bourbons decided self day begin liking whiskey petitioned bartender make something awesome whiskey kind drink want inquired idea good sir see neophyte tyro fledgling comes spirits perhaps banter quite level time already drinks visit franklin mortgage remember going thought proceeded mix craziest drink ever seen whiskey orange bitters egg white portuguese red wine stuff verdict delicious also commodore drink menu good drinks little pricey set back around friends arrived seated outside got try village burger short rib cheddar duck fat fries burger comes artfully restrained dollop homemade thousand island dressing unbelievable applewood bacon dressing served elevate already incredible taste meat wait come back order another one fries good think next time stick plain duck fat fries friends ordered super crispy delicious warning place gets insanely busy might wait pretty long time table drinks great food delectable staff knowledgeable personable would totally come back still dreaming burger chris',
#  'great location great food friendly staff seats store gets pretty crowded people waiting food saw lot online order ready go counter think would smart move next time want come weekday lunch rush weather permitting great grab hcv eat rittenhouse square across street come times friends coworkers one complained choices vegetarians meat eaters alike',
#  'came group four great experience tons interesting appetizers try dumplings corn mushrooms wings specials escaping us also got order noodles chinatown noodle house portions also chinatown noodle house ingredients interesting fresh tasty plus great deal byo boot great addition th street',
#  'combination deals make rolls sushi super cheap rolls definitely smaller side need order combination deal want get full sashimi actually fresh thought would considering price also joint sort small service slow place byo head downstairs bring beers waiting',
#  'cool spot great location got early crushing crowds others talked bartenders awesome made perfect rye manhattan rocks never one hooked easily best burger ever absolutely back',
#  'everything want take food fresh yummy relatively healthy also love good go place northern liberties convenient enough',
# ...
#  'chef buys fried chicken place soul food spot good consistant always call ahead',
#  'brunch solid got stack friends got french toast w brie cheese coffee good wait time minimal service great highly recommended',
#  'fried meat dumplings general tso dinner box gave four stars let clarify greasy unhealthy american chinese food thats cheap way much salt know serve general tso china right cheap solid dinner general tso dinner box typical combo egg roll rice chicken pretty good say average stars nothing sticks real reason order golden chopsticks quite often fried meat dumplings thick heavy doughy dumplings thin potstickers might used get order less bucks lot food make sure sleep water next bed salty good way aiming pretty decent job skip dumplings',
#  'think might even like tria smidge better rittenhouse location sitting litlte upstairs section much breathing space smaller th st spot waitress good ones previous locations super cheerful adorable prompt checking drinks clearing away plates went today check pliny younger ensuing scene little chaotic maybe drink tickets would easier two lines either side store best could letting people time restaurant filled worried friend running late like beer allowed problems letting host know waiting food also delicious shared asturian blue cheese nicely complimented blackberry sauce wild mushroom sandwich lovely lemony flavor boyfriend three cheese sandwich ordered quite good friend truffled egg toast also tried one standout starter items yet disappointed experience tria either location even crazy extenuating circumstances',
#  'one favorite restaurants fairmont area zorba byob traditional greek dishes prices reasonable well appetizer sampler really good filling fan lamb tried several stewed dishes never let quaint restaurant definitely try',
#  'best pizza neighborhood better nypd zios pandora etc highly recommend personal size one person eggplant pizza outstanding also big fan sausage mushroom sausage actual slices italian sausage nasty crumbly bits get lot places prices reasonable impressed rest menu pizza near jefferson think better burgers bad',
#  'wandered slate wait brunch day day longer willing wait unfortunately getting seated immediately slate imply get food faster two people restaurant party six seated despite emptiness food somehow took minutes make asked status meal told best keep mind six top without reservation personally think reservation seems rather irrelevant restaurant plenty open tables conclusion experienced better faster service time brunch good enjoyed frittatas home fries chips although may hunger talking',
#  'dined busy saturday evening dinner concert everyone else commented first courses foie gras soup pork belly dishes excellent full flavor second courses octopus sea bream also met expectations cooked perfection one entree particular however especially disappointing two preceding fabulous courses majority roast pork entree edible hurry get concert definitely would sent back one rectangular supposed piece roast pork cut pork found instead white cubes pork fat less cm discernable pork meat dish stated pork belly would understand menu clearly stated roast pork dish meat disbelief could even serve dish inedible unless enjoy pure fat dish sadly cannot recommend establishment based last course',
#  'regular tasting menu bottles wine possibly best meal ever chef clearly focuses great textures selecting key ingredients strong flavors right pigs feet meatballs outstanding service absolutely perfect much appreciated eaten another place felt rushed dinner absolutely excellent',
#  'new restaurant neighborhood finally opened saturday wandered high expectations good variety vietnamese food ample amount food tasty good value',
#  'place exactly advertised showed noon saturday place busy able grab last two seats bar village burger incredible whiskey tried highly recommend manhattan one best anywhere',
#  'always go prohibition taproom probably yards brawler b c huge beer drinker know like brawler might try another british style beer always order beer battered green beans b c light refreshing feel like unhealthy complain loudness small room acoustics seriously control starts fill almost always full honestly would probably go bit way far local places going troc seeing show arts underground always make prohibition stop nice accommodating staff nice clean decor nice food dig',
#  'went monday night early seated right away waiter friendly efficient food delicious plentiful would definitely go back',
#  'absolute worst sat min counter waiting tuna sandwich staff friendly place old dirty insane good location could got act together horrible miss billy g',
#  'came grab couple beers thursday night surprisingly busy given place opened supposedly side project folks farmer cabinet tell based lighting lack thereof thank god hostess led us stairs see damn thing enough whining let get back important stuff taps downstairs keep local taps upstairs bar pleased engine market stout philadelphia brewing company recommendation bartender rocco clearly knew beers also able recommend successfully make cocktails friends also personable food menu looked really good coming soon section unsure actually available last night intrigued turnip kimchi apparently comes hot dogs definitely back try update yelp review accordingly summarize great place beer aficionados vampires torn giving stars figure always go try food',
#  'ordered pork roll spring rolls extremely disappointed dry consistency suspicious contents primarily tendon overall pho mediocre compare vietnam palace may continue go convenience',
#  'couple invite us bastille day wanted go bst back day never made really list got invite glad accept good friends assumed food decent worst sounded like fun setting big warehouse style building somewheres th floor overlooking quasi industrialish part river crowd well bit older median age restaurant take space try make many tables possible window overlooking river ok let get food opposite husband ordered crab gallette big sharer couples look good somewhere cake mousse finished wife got vegetarian app lots good choices menu imo order whatever ordered escargots sauteed mushrooms red burgundy sauce honestly dish ela stateside add lil jazz hipsters would going batshit crazy good dish red burgundy sauce matched snails mushrooms well grab extra roll sop kind sauce snails nice tender wife got cold local corn soup well executed huge cold corn fan summer sweet mains opposing husband got salmon looked ok seemed bit better done prefer struggle time sauce looked nice got scallop dish sauteed veggies potatoes bouillabaise sauce nice sauce excellent scallops cooked properly home run good food wife got home run hangar steak cooked medium rare sliced red burgundy sauce side green lentils hangar perfectly cooked extra meaty flavor good hangar steak burgundy sauce right wonderful dish order desert deal apps bucks escargots crazy cheap entrees ish good quality less many places wine moore brothers stuff trophy wines wine meant good drinking wine food reasonably priced hipster list right food good price renamed restaurant reopened different section city might packed unfortunate way things work friends invite means go enjoy',
#  'phenomenal brunch experience poached eggs buttermilk biscuits pork confit delightful right size service impeccable friendly watchful orange juice water regularly filled live jazz weekend brunch restaurant beautiful cozy menu small uncreative food high quality decently priced rittenhouse square mentioned plate oj good experience',
#  'easy fast order way go delicious best lamb biryani ever',
#  'saturday night market st philly swarming people friends checked restaurants hour long waits wait anjou non existant red flag right starving couscous menu april fave menu cheap food sounded good marco karina ordered chilean sea bass w tarot puree heart palm salad atop miso glaze april ordered pan seared red chile norwegian salmon sweet peas couscous sun dried tomato red pepper sauce seriously craving couscous fourth companion megan ordered bi bim bap medley vegetable egg julienne served two traditional korean sauces bowl miso soup available without beef opted french cut chicken breast wasabi gnocchi wild mushrooms asparagus sweet garlic ginger sauce sounds delicious yeah thought first problem chip glass sharp enough cut lip get cut could mention plastic shard cheesecake waitress apologized gave fresh glass fine biggie second problem ran gnocchi chicken tried push mashed potatoes hey make home dollar thanks said risotto fine biggie third problem long wait restaurant busy sure like take time maybe trying lure unsuspecting people outside pretending full happening place like rest friends interest part marketing gimmick wanted fed food better worth wait fourth problem finally received entrees immediately recognized problem april poor innocent patron ordered salmon couscous received plate looking barren piece salmon size shape sleeve laffy taffys halves asparagus couscous big biggie couscous blurted noticed nearly dishes missing crucial elements menu chilean sea bass served mashed taro hearts palm salad ring mashed potatoes maybe asked french cut meant know means slice chicken breast thin flat possible try cover plate keep costs wild mushrooms must gone loco nowhere plate maybe partying asparagus also risotto oh right resting plate like pale sticky dome something resembled mashed potatoes since okay able scoop risotto ice cream scooper happy campers went hunger strike host went back kitchen find happened came back informed us ran couscous mashed taro gnocchi wild mushrooms back lb bag instant mashed potatoes rest blur remember telling host waiter customer service change order without asking patron fine agreed took care drinks ordered much right still left tip waitress felt horrible tell family friends works left still hungry livid waitress outside crying smoking cigarette poor girl hope moves decent establishment like hooters fudruckkers wish well us went street soho pizza scarfed scrumptious slices piece ordered mushroom broccoli pizza mushrooms broccoli appeared slice see people anjou unless want mashed potatoes go edit come attention dreadful place closed victory',
#  'gelato world philadelphia gotta kidding someone studied abroad italy skeptical long lost college friend fiance brought capogiro boy glad took dead wrong question place usually strawberry chocolate kind girl perusing selection flavors disappointed see single berry flavor caught sign said avocado trust us avocado lover asked sample amazeballs seriously ordered small cone avocado nutella never go wrong nutella anything hands say best gelato ever creamy smooth packed refreshing flavor complaint small cone costs poor med student steep price sweet indulgence',
#  'visiting town excited visit chef milly newly opened restaurant sore disappointment waited even w reservation tried patient since recently opened chef milly even offer smile visitors food ok definitely worth wait commend server think name ty professionalism even amongst multiple jobs tasked chef ramsey would highly disappointed surely',
#  'absolutely disgusting favor never order food terrible',
#  'several friends continued mini pub crawl mixology bars begun franklin mortgage investment co good move parked bar got show sasha bartender kept friendly banter us even concocted variety beverages throughout course stay cocktail menu fairly extensive broken prohibition repeal era drinks mention long lists bourbons ryes scotches ordered aviation drink make brandied cherries right way creme de violette tint blue like sky sasha let take look bottle perhaps know awful curacao another friend created drink art age mechanical reproduction root liqueur made roots herbs used old fashioned root beer chocolate bitters seltzer orange also partook food first duck fat fries trend chicago live least year never never eaten anything involving duck suppose lost duck fat innocence thick cut rich taste gratis duck fat one presumes actually greasy definitely better ordered cup cheese sauce side also got soft pretzel sticks would fine especially remarkable without mustard sauce distinct taste raspberry mind pooled cup underneath overall friendly place fab drinks great food wish city',
#  'basically neighborhood corner bar port richmond parking bit problem service always good looking good beers place bud coors etc local shot beer type place never tried anything food front cannot comment kitchen usually local cover bands weekends cover family friends played fun place',
#  'delightful find way back home long afternoon walking tour longwood gardens decided try good old fashioned neighborhood crawl one little italian neighborhood restaurant gems south philly well known tre scalini came number yelp based current location despite commercially developed location looking othere restaurants small block extrememly glad decided go anyway reservation dressed rather casually despite fact saturday night busy pretty booked tre able work us absolutely waiting kudos efforts since others already reviewed menu offerings going add dare say mood looks good menu atmosphere elegant south philadelphia italian cozy warm servers treated us like royalty extremely attentive despite fact still rather natty sneakers knew menu dinner specials inside small task assure parking tough town bring pay valet parking bucks pete sake stick stop searching find spot well worth time effort make sure pay parking fees theppa never takes break writing tickets city large amount revenue generated restaurant districts recommend tre scalini enough asked better meal dining experience charles g chuck boulais clu mcp http www adultmedsupply com',
#  'town business burger cooked med rare perfection whole patty makes wonder sous vide give quick sear meat quality lacked proper seasoning foie gras absolutely business adorning burger also contains overwhelming flavors bleu cheese bacon even burger matter almost dumb concept kobe burger event gimmick thats worked well restaurant sure took mine ate separately delicious recommend want taste extra spending deviled eggs pass nothing replicate google search ability properly boil eggs',
#  'remember great restaurant decades ago walking heading indian food one companion tells us g r makeover go well may changed management menu forgot introduce kitchen staff spice shelf chicken mole looked nice sauce zero taste steak tacos done good meat diner asked wanted steak way rarer likes steak totally unseasoned pizazz back',
#  'used live doors las cazuelas went faithfully food delicious dont know still make chilean sea bass pumpkin mole one tastiest things ever eaten husband visited last sunday brunch ordered ton food gift certificate use highly reccommend huevos divorciados omlette poblano poblano mushroom lover oaxaca cheese melts eggs veggies wonderful way husband divorciados unusual tasty favorite las cazuelas tacos steak fresh onions cilantro far winner book confess dreamed often cannot resist urge go get big plate tried marinated steak tacos time like much red coating marinade steak overwhelming could taste yummy meat grilled flavor great regular steak tacos husband loved shredded pork tacos thought ok shrimp tacos always winner taste fresh crisp light suppose pure flavors usually treat fresh ingredients brings back time veer away overly marinated items future always cafe de olla coffee cinnamon desserts good tell everyone place always bring option folks town keep great work',
#  'good beer menu great food options chicken fingers killer especially mac house gravy fries see sweet sausage p special menu pounce',
#  ...]

# %%
# Feature extraction
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(corpus)

print(X.shape)
# Out:
# (687289, 153651)

# %%
n_topics = 8

lsa_model = TruncatedSVD(n_components=n_topics)
lsa_topic_matrix = lsa_model.fit_transform(X)

# %%
# Define helper functions
def get_keys(topic_matrix):
    '''
    returns an integer list of predicted topic 
    categories for a given topic matrix
    '''
    keys = topic_matrix.argmax(axis=1).tolist()
    return keys

def keys_to_counts(keys):
    '''
    returns a tuple of topic categories and their 
    accompanying magnitudes for a given list of keys
    '''
    count_pairs = Counter(keys).items()
    categories = [pair[0] for pair in count_pairs]
    counts = [pair[1] for pair in count_pairs]
    return (categories, counts)

def get_top_n_words(n, keys, document_term_matrix, count_vectorizer):
    '''
    returns a list of n_topic strings, where each string contains the n most common 
    words in a predicted category, in order
    '''
    top_word_indices = []
    for topic in range(n_topics):
        temp_vector_sum = 0
        for i in range(len(keys)):
            if keys[i] == topic:
                temp_vector_sum += document_term_matrix[i]
        temp_vector_sum = temp_vector_sum.toarray()
        top_n_word_indices = np.flip(np.argsort(temp_vector_sum)[0][-n:],0)
        top_word_indices.append(top_n_word_indices)   
    top_words = []
    for topic in top_word_indices:
        topic_words = []
        for index in topic:
            temp_word_vector = np.zeros((1,document_term_matrix.shape[1]))
            temp_word_vector[:,index] = 1
            the_word = count_vectorizer.inverse_transform(temp_word_vector)[0][0]
            topic_words.append(the_word.encode('ascii').decode('utf-8'))
        top_words.append(" ".join(topic_words))         
    return top_words

# %%
lda_model = LatentDirichletAllocation(n_components=n_topics, learning_method='online', 
                                          random_state=0, verbose=0)
lda_topic_matrix = lda_model.fit_transform(X)

# %%
lda_keys = get_keys(lda_topic_matrix)
lda_categories, lda_counts = keys_to_counts(lda_keys)

# %%
top_n_words_lda = get_top_n_words(10, lda_keys, X, vectorizer)

for i in range(len(top_n_words_lda)):
    print("Topic {}: ".format(i+1), top_n_words_lda[i])
# Out:
# Topic 1:  good place food like great get cheese one go really
# Topic 2:  good food delicious great like sauce ordered dish also one
# Topic 3:  chocolate cake pizza cream donuts good ice best like sweet
# Topic 4:  food us place service time good one like would order
# Topic 5:  food great place good service back delicious really menu restaurant
# Topic 6:  beer like food bar place good one great get go
# Topic 7:  coffee place great good food breakfast like philly one brunch
# Topic 8:  food good place like chicken great really also ordered rice

# %%
lda_topic_matrix.shape
# Out:
# (687289, 8)

# %%
# add the topics to this dataset as 8 new columns
column_names = ['topic_{}'.format(i+1) for i in range(n_topics)]
topics = pd.DataFrame(lda_topic_matrix, columns=column_names)
reviews = pd.concat([reviews, topics], axis=1)
reviews.to_csv("reviews_topics_user.csv")

reviews
# Out:
#                      review_id                 user_id  stars_x  \
# 0       AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ      5.0
# 1       JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A      1.0
# 2       8JFGBuHMoiNDyfcxuWNtrA  smOvOajNG0lS4Pq7d8g4JQ      4.0
# 3       oyaMhzBSwfGgemSGuZCdwQ  Dd1jQj7S-BFGqRbApFzCFw      5.0
# 4       Xs8Z8lmKkosqW5mw_sVAoA  IQsF3Rc6IgCzjVV9DE8KXg      5.0
# ...                        ...                     ...      ...
# 687284  Wrt6pZizQzw-ZTKrvMwrGw  ua6QuBe6mar6pDrhHETzJQ      2.0
# 687285  X5R98ygOtbhryDiKA-J2qQ  LHWtjTG7e1NzNPYUbUo-9w      5.0
# 687286  MVg4YUQeEhCA7Z7RsBJSVg  7-7A0Avj47slLGV7yBFc8w      3.0
# 687287  nLjbVsETpqO17RbFcqskkA  am7-gkH_PDz598oTdYSD6A      3.0
# 687288  cACxcUY_AIsQKkpDRXuqnw  MCzlzlOw7IGbRAKVjJBPtg      3.0
#
#                                                      text  liked   topic_1  \
# 0       Wow!  Yummy, different,  delicious.   Our favo...      1  0.313264
# 1       I am a long term frequent customer of this est...      0  0.297167
# 2       Good food--loved the gnocchi with marinara\nth...      1  0.007362
# 3       Tremendous service (Big shout out to Douglas) ...      1  0.005212
# 4       My absolute favorite cafe in the city. Their b...      1  0.565553
# ...                                                   ...    ...       ...
# 687284  Ok, I have to say, after living on this block ...      0  0.111870
# 687285  I've been to the other Federal Donuts location...      1  0.320783
# 687286  I was so excited about all the food I saw, but...      0  0.215101
# 687287  *Later Yelp* I've only been here once, but I l...      0  0.003794
# 687288  This is a good pizza option - they deliver thr...      0  0.373810
#
#          topic_2   topic_3   topic_4   topic_5   topic_6   topic_7   topic_8
# 0       0.313915  0.005438  0.254500  0.005445  0.005442  0.005436  0.096559
# 1       0.035878  0.003572  0.649079  0.003580  0.003576  0.003574  0.003574
# 2       0.146414  0.065403  0.007363  0.751392  0.007353  0.007353  0.007360
# 3       0.079793  0.005209  0.005212  0.748513  0.145623  0.005225  0.005212
# 4       0.003054  0.071990  0.003056  0.071111  0.003053  0.159809  0.122374
# ...          ...       ...       ...       ...       ...       ...       ...
# 687284  0.001052  0.001052  0.364793  0.063413  0.001052  0.053158  0.403610
# 687285  0.052310  0.097361  0.001987  0.130098  0.097764  0.177424  0.122272
# 687286  0.005958  0.059662  0.303467  0.096133  0.164183  0.149531  0.005965
# 687287  0.126797  0.064905  0.048054  0.593378  0.003798  0.003792  0.155481
# 687288  0.108661  0.172748  0.238113  0.001814  0.101224  0.001816  0.001814
#
# [687289 rows x 13 columns]

# %% [markdown]
# # NEED TO FILTER FOR USERS THAT REVIEWED AT LEAST 5 TIMES

# %%
# Average topic distribution for items user interacted with only liked items
user_profile = reviews[reviews["liked"] == 1].drop(columns=['review_id', 'stars_x', 'text']).groupby("user_id", as_index=False)[column_names].mean()
user_profile.to_csv("user_profiles.csv")

user_profile
# Out:
#                        user_id   topic_1   topic_2   topic_3   topic_4  \
# 0       ---r61b7EpVPkb4UVme5tA  0.149137  0.005005  0.005000  0.395696
# 1       --0kuuLmuYBe3Rmu0Iycww  0.373362  0.160772  0.122085  0.005390
# 2       --2tyArRmSoyKx5r-FVG0A  0.257389  0.009424  0.013265  0.180111
# 3       --2vR0DIsmQ6WfcSzKWigw  0.033140  0.009672  0.812296  0.013007
# 4       --4AjktZiHowEIBCMd4CZA  0.206812  0.005182  0.017323  0.049723
# ...                        ...       ...       ...       ...       ...
# 159922  zzrhWsiCwAKQzbgMZIOtgg  0.230308  0.045626  0.063714  0.082449
# 159923  zztAOHhlNfNzOxUeyxeyFw  0.356585  0.005961  0.005957  0.005964
# 159924  zzvCl_egPyWpxO7EvWc2IA  0.004241  0.067078  0.004237  0.149818
# 159925  zzwYLnmIvj8C7wJmRjtkRA  0.042339  0.122963  0.006520  0.006525
# 159926  zzx7J3zheFF3zf5YYfDAMg  0.005443  0.058935  0.005437  0.005456
#
#          topic_5   topic_6   topic_7   topic_8
# 0       0.430137  0.005009  0.005001  0.005015
# 1       0.156996  0.170622  0.005386  0.005387
# 2       0.185537  0.197084  0.096957  0.060232
# 3       0.012538  0.021357  0.097229  0.000761
# 4       0.425025  0.080224  0.049057  0.166654
# ...          ...       ...       ...       ...
# 159922  0.372313  0.085547  0.103842  0.016201
# 159923  0.430900  0.122631  0.066047  0.005957
# 159924  0.644001  0.059269  0.067116  0.004239
# 159925  0.709200  0.099399  0.006525  0.006529
# 159926  0.482066  0.005439  0.005440  0.431783
#
# [159927 rows x 9 columns]

# %%
frequent_users = reviews[reviews['liked'] == 1]['user_id'].value_counts() > 5
frequent_users.sum()
# Out:
# 14626

# %% [markdown]
# # NEED TO FILTER FOR RESTAURANTS THAT WERE REVIEWED AT LEAST 5 TIMES

# %%
reviews_topic = pd.read_csv("reviews_topics_user.csv")
reviews_topic = pd.concat([reviews_topic, reviews['business_id']], axis=1)
reviews_topic = reviews_topic.drop(columns=['Unnamed: 0', 'review_id', 'user_id', 'stars_x', 'text'])
restaurant_profile = reviews_topic[reviews_topic['liked'] == 1].groupby("business_id", as_index=False)[column_names].mean()
restaurant_profile.to_csv("restaurant_profiles.csv")
restaurant_profile
# Out:
#                  business_id   topic_1   topic_2   topic_3   topic_4  \
# 0     -0M0b-XhtFagyLmsBtOe8w  0.078602  0.046403  0.022593  0.140175
# 1     -0PN_KFPtbnLQZEeb23XiA  0.402912  0.018541  0.005863  0.084059
# 2     -0TffRSXXIlBYVbb5AwfTg  0.108954  0.216670  0.018824  0.104431
# 3     -0eUa8TsXFFy0FCxHYmrjg  0.418875  0.053791  0.043648  0.096559
# 4     -1B9pP_CrRBJYPICE5WbRA  0.082961  0.078748  0.013261  0.108814
# ...                      ...       ...       ...       ...       ...
# 5772  zxY4DgtXsVHihSUpsmwamg  0.641424  0.130154  0.012577  0.066264
# 5773  zy7uNOvpykrq-XlmDY_wHA  0.248098  0.050230  0.022135  0.199817
# 5774  zyMkbavgHASQtqVwaock9A  0.678724  0.030783  0.018321  0.031066
# 5775  zz-fcqurtm77bZ_rVvo2Lw  0.463548  0.108644  0.059583  0.041887
# 5776  zzyx5x0Z7xXWWvWnZFuxlQ  0.603816  0.093469  0.122769  0.003053
#
#        topic_5   topic_6   topic_7   topic_8
# 0     0.436417  0.175497  0.080066  0.020248
# 1     0.078386  0.047164  0.063135  0.299939
# 2     0.367122  0.047990  0.033901  0.102109
# 3     0.211321  0.037843  0.081673  0.056292
# 4     0.360558  0.038375  0.020408  0.296874
# ...        ...       ...       ...       ...
# 5772  0.075898  0.037468  0.031334  0.004880
# 5773  0.365974  0.024520  0.074811  0.014414
# 5774  0.141033  0.033699  0.032831  0.033543
# 5775  0.111181  0.117334  0.068131  0.029690
# 5776  0.003053  0.074058  0.096726  0.003055
#
# [5777 rows x 9 columns]

# %%
frequent_restaurants = reviews_topic[reviews_topic['liked'] == 1]['business_id'].value_counts() > 5
frequent_restaurants.sum()
# Out:
# 4726

# %%
user_profile = pd.read_csv("user_profiles.csv")
user_profile = user_profile.drop(columns=['Unnamed: 0'])
restaurant_profile = pd.read_csv("restaurant_profiles.csv")
restaurant_profile = restaurant_profile.drop(columns=['Unnamed: 0'])

# %%
# Recommendations

# select one user
user_id = "---r61b7EpVPkb4UVme5tA"
usr_lst = user_profile[user_profile['user_id'] == user_id].drop(columns=['user_id']).values

# removing the restaurants already visited by the user
visited_restaurants = reviews[reviews['user_id'] == user_id]['business_id'].values # including even the ones the user didn't like
new_restaurants = restaurant_profile[-restaurant_profile['business_id'].isin(visited_restaurants)]
new_restaurants.reset_index(drop=True, inplace=True)

# business matrix
bus_matrix = new_restaurants.drop(columns=['business_id']).values

# Compute similarity between user profile and all document topics
similarity_scores = cosine_similarity(usr_lst, bus_matrix)

# Recommend items with highest similarity scores
N = 5
recommended_indices = similarity_scores.argsort()[0][::-1][:N]  # Top N recommendations
restaurant_profile.iloc[recommended_indices]["business_id"]
# Out:
# 5088    sDaBm5V1VQMOPfCm76turg
# 4495    l_FzESKdJPs41Ll5y35xUg
# 343     2hCIzMXhSbgObLS4al82rg
# 3185    YRw-uBpdzRZngN6zzoC4WA
# 2124    MYoRNLb5chwjQe3c_k37Gg
# Name: business_id, dtype: object

# %% [markdown]
# # Doc2Vec

# %% [markdown]
# This takes the text completely untreated. Maybe we can look into the possibility of normalizing it before.

# %% [markdown]
# Less than 2 minutes with the 10000 sample

# %%
# Filtering for users and restaurants that have at least 5 reviews posted/received

# counts
user_counts = reviews['user_id'].value_counts()
restaurant_counts = reviews['business_id'].value_counts()

# creating filters
users_with_5_plus_reviews = user_counts[user_counts >= 5].index
restaurants_with_5_plus_reviews = restaurant_counts[restaurant_counts >= 5].index

# applying filters to reviews df
filtered_reviews = reviews[
    (reviews['user_id'].isin(users_with_5_plus_reviews)) &
    (reviews['business_id'].isin(restaurants_with_5_plus_reviews)) &
    (reviews['liked'] == 1)
]

filtered_reviews.reset_index(drop=True, inplace=True)
filtered_reviews
# Out:
#                      review_id                 user_id  \
# 0       8JFGBuHMoiNDyfcxuWNtrA  smOvOajNG0lS4Pq7d8g4JQ
# 1       Xs8Z8lmKkosqW5mw_sVAoA  IQsF3Rc6IgCzjVV9DE8KXg
# 2       JBWZmBy69VMggxj3eYn17Q  aFa96pz67TwOFu4Weq5Agg
# 3       cvQXRFLCyr0S7EgFb4lZqw  ZGjgfSvjQK886kiTzLwfLQ
# 4       r2IBPY_E8AE5_GpsqlONyg  IKbjLnfBQtEyVzEu8CuOLg
# ...                        ...                     ...
# 287601  ZcEx4UEnTnR_TEPEqwkKjA  gkg9VqsxPCgpfYXO1dl8CA
# 287602  rtt1Ymczj-1Lb26JMsY2lA  M1cMsRL4L7IUr9RILDywEQ
# 287603  me7QTotYCOjWNVA8bzN1eg  bJ5FtCtZX3ZZacz2_2PJjA
# 287604  5n_oSwXspiiSsZgNwjp48g  bJ5FtCtZX3ZZacz2_2PJjA
# 287605  X5R98ygOtbhryDiKA-J2qQ  LHWtjTG7e1NzNPYUbUo-9w
#
#                    business_id  stars_x  \
# 0       RZtGWDLCAtuipwaZ-UfjmQ      4.0
# 1       eFvzHawVJofxSnD7TgbZtg      5.0
# 2       kq5Ghhh14r-eCxlVmlyd8w      5.0
# 3       EtKSTHV5Qx_Q7Aur9o4kQQ      5.0
# 4       VJEzpfLs_Jnzgqh5A_FVTg      4.0
# ...                        ...      ...
# 287601  Ea663rIHyKXz2VP2DPH7Cg      4.0
# 287602  vt_esoDw6HG5ClM12OPkMg      4.0
# 287603  wMQkdK2aNMvq2xoojC98Mw      4.0
# 287604  SOsjW1JARmtHUFtpFlp8rw      4.0
# 287605  rgeuy1qbw6Z8B6CSVANHIA      5.0
#
#                                                      text  liked
# 0       Good food--loved the gnocchi with marinara\nth...      1
# 1       My absolute favorite cafe in the city. Their b...      1
# 2       My boyfriend and I tried this deli for the fir...      1
# 3       On a scale of one to things that are awesome, ...      1
# 4       It was my fiance's birthday and he decided he ...      1
# ...                                                   ...    ...
# 287601  I decided to try this place out after Christma...      1
# 287602  5 stars for the Bonte waffle, 3 stars for this...      1
# 287603  South Street Diner isn't the best of Philly Di...      1
# 287604  When I first heard that the Peace A Pizza (htt...      1
# 287605  I've been to the other Federal Donuts location...      1
#
# [287606 rows x 6 columns]

# %%
sample = filtered_reviews.sample(10000).reset_index(drop=True)
sample
# Out:
#                    review_id                 user_id             business_id  \
# 0     sLC4-3d74U8ZB8-ZjVsSkQ  tCqMd0ZG3B8vi2KOxReW1Q  i_FWONQD1ZBqrNE2b-M5Ug
# 1     XPKAYjFeHchaGeXj_9I9OQ  0iBwDU_88feB_Drpmjkx-g  7pwZZVVlYCxQvVdd8Q03wg
# 2     CAbVpMMfAEu0y5rjzFFVsA  K1Z4CV1kCmvLYJnA30yfAw  U7HYUH8SqZO6OQMNKCr5kQ
# 3     6dXF_yq-525ksUiwhGCCNQ  55fCofuKVb7XP3newzmX3w  tf2nzjkP8XGIeU-lg767XA
# 4     wtyetieCLcewtXSKaeJBeQ  UV41Cu3ZdhPaYCDa8uPL8g  benTAK8255VkJu14ZxVtDQ
# ...                      ...                     ...                     ...
# 9995  L7d6ernOCVXlikiP5OFIWg  n1OrzdUywZXcvrRa7bfQag  y6-J_UjNk69VNLb39c_5CA
# 9996  T-UnHI0o6rPSt4beq0CZjA  3ZtKlGT9UNCv0tqVsiimkg  FIFi_8eNmc-jPHZVHPS3NQ
# 9997  KDAIeB1ZDzvCVOLlgjLncA  vFd8aBLg1kFcd0kCkoi-xw  G9LZoNlCfRH941q87_JLIg
# 9998  ZZMJlcWZ1J9piomyl2Sltw  uRwxr1xulZk3g8_eimR6tA  LzVvcVm48zYIcQnwLKt1oA
# 9999  5eFGXwwq7B6R9LezgoCJZQ  IXRk16mfwYskubKioHDzYg  kZ1q0K13tFYG_ZJrVvsJHA
#
#       stars_x                                               text  liked
# 0         5.0  This and Suraya are our go to restaurant when ...      1
# 1         5.0  Best pizza I've tasted in south philly....I ha...      1
# 2         5.0  Holy ba-jesus this place is GREAT! Mooooove ov...      1
# 3         4.0  I've been here for drinks at the bar before an...      1
# 4         4.0  Great addition to the neighborhood! My husband...      1
# ...       ...                                                ...    ...
# 9995      5.0  I had a good experience and it was a lot of fu...      1
# 9996      4.0  Came here after hearing so many great reviews ...      1
# 9997      4.0  The esquites is a good way to start your meal ...      1
# 9998      5.0  Ok. Seriously I don't know where to begin! I g...      1
# 9999      4.0  Overall Rating: 3.5/5 (rounded up to 4) \n\nIn...      1
#
# [10000 rows x 6 columns]

# %%
data = sample['text']

# preproces the documents, and create TaggedDocuments
tagged_data = [TaggedDocument(words=word_tokenize(doc.lower()),
							tags=[str(i)]) for i,
			doc in enumerate(data)]

# Doc2vec model
model = Doc2Vec(vector_size=100,
				min_count=2, epochs=50)
model.build_vocab(tagged_data)
model.train(tagged_data,
			total_examples=model.corpus_count,
			epochs=model.epochs)

# document vectors
document_vectors = [model.infer_vector(
	word_tokenize(doc.lower())) for doc in data]

# %%
sample['doc2vec'] = pd.Series(document_vectors)

# %%
sample
# Out:
#                    review_id                 user_id             business_id  \
# 0     sLC4-3d74U8ZB8-ZjVsSkQ  tCqMd0ZG3B8vi2KOxReW1Q  i_FWONQD1ZBqrNE2b-M5Ug
# 1     XPKAYjFeHchaGeXj_9I9OQ  0iBwDU_88feB_Drpmjkx-g  7pwZZVVlYCxQvVdd8Q03wg
# 2     CAbVpMMfAEu0y5rjzFFVsA  K1Z4CV1kCmvLYJnA30yfAw  U7HYUH8SqZO6OQMNKCr5kQ
# 3     6dXF_yq-525ksUiwhGCCNQ  55fCofuKVb7XP3newzmX3w  tf2nzjkP8XGIeU-lg767XA
# 4     wtyetieCLcewtXSKaeJBeQ  UV41Cu3ZdhPaYCDa8uPL8g  benTAK8255VkJu14ZxVtDQ
# ...                      ...                     ...                     ...
# 9995  L7d6ernOCVXlikiP5OFIWg  n1OrzdUywZXcvrRa7bfQag  y6-J_UjNk69VNLb39c_5CA
# 9996  T-UnHI0o6rPSt4beq0CZjA  3ZtKlGT9UNCv0tqVsiimkg  FIFi_8eNmc-jPHZVHPS3NQ
# 9997  KDAIeB1ZDzvCVOLlgjLncA  vFd8aBLg1kFcd0kCkoi-xw  G9LZoNlCfRH941q87_JLIg
# 9998  ZZMJlcWZ1J9piomyl2Sltw  uRwxr1xulZk3g8_eimR6tA  LzVvcVm48zYIcQnwLKt1oA
# 9999  5eFGXwwq7B6R9LezgoCJZQ  IXRk16mfwYskubKioHDzYg  kZ1q0K13tFYG_ZJrVvsJHA
#
#       stars_x                                               text  liked  \
# 0         5.0  This and Suraya are our go to restaurant when ...      1
# 1         5.0  Best pizza I've tasted in south philly....I ha...      1
# 2         5.0  Holy ba-jesus this place is GREAT! Mooooove ov...      1
# 3         4.0  I've been here for drinks at the bar before an...      1
# 4         4.0  Great addition to the neighborhood! My husband...      1
# ...       ...                                                ...    ...
# 9995      5.0  I had a good experience and it was a lot of fu...      1
# 9996      4.0  Came here after hearing so many great reviews ...      1
# 9997      4.0  The esquites is a good way to start your meal ...      1
# 9998      5.0  Ok. Seriously I don't know where to begin! I g...      1
# 9999      4.0  Overall Rating: 3.5/5 (rounded up to 4) \n\nIn...      1
#
#                                                 doc2vec
# 0     [-0.45106882, 0.03996058, 1.1453925, -1.439583...
# 1     [-0.31197488, 0.7667, -0.30364245, -1.3111172,...
# 2     [-2.5873663, 0.85221237, -1.8083317, -3.284638...
# 3     [0.63472456, 2.3002424, -1.4746091, -0.8441891...
# 4     [-0.010030669, -0.83387834, -3.2065663, 0.2614...
# ...                                                 ...
# 9995  [0.24692239, 0.28317174, -0.6580293, -0.288496...
# 9996  [-0.3912266, 1.0629753, -0.8093995, 0.04401463...
# 9997  [-0.4884597, 0.5126089, -0.102682665, -0.78100...
# 9998  [0.34513474, -1.5451471, -1.2362162, 0.3502437...
# 9999  [0.86594343, -2.8260567, -2.367219, -0.2410634...
#
# [10000 rows x 7 columns]

# %%
sample_expanded = pd.DataFrame(sample['doc2vec'].tolist(), index=sample.index)
sample_expanded.columns = [f'doc2vec_{i}' for i in range(sample_expanded.shape[1])]
sample = sample.drop('doc2vec', axis=1).join(sample_expanded)

sample
# Out:
#                    review_id                 user_id             business_id  \
# 0     sLC4-3d74U8ZB8-ZjVsSkQ  tCqMd0ZG3B8vi2KOxReW1Q  i_FWONQD1ZBqrNE2b-M5Ug
# 1     XPKAYjFeHchaGeXj_9I9OQ  0iBwDU_88feB_Drpmjkx-g  7pwZZVVlYCxQvVdd8Q03wg
# 2     CAbVpMMfAEu0y5rjzFFVsA  K1Z4CV1kCmvLYJnA30yfAw  U7HYUH8SqZO6OQMNKCr5kQ
# 3     6dXF_yq-525ksUiwhGCCNQ  55fCofuKVb7XP3newzmX3w  tf2nzjkP8XGIeU-lg767XA
# 4     wtyetieCLcewtXSKaeJBeQ  UV41Cu3ZdhPaYCDa8uPL8g  benTAK8255VkJu14ZxVtDQ
# ...                      ...                     ...                     ...
# 9995  L7d6ernOCVXlikiP5OFIWg  n1OrzdUywZXcvrRa7bfQag  y6-J_UjNk69VNLb39c_5CA
# 9996  T-UnHI0o6rPSt4beq0CZjA  3ZtKlGT9UNCv0tqVsiimkg  FIFi_8eNmc-jPHZVHPS3NQ
# 9997  KDAIeB1ZDzvCVOLlgjLncA  vFd8aBLg1kFcd0kCkoi-xw  G9LZoNlCfRH941q87_JLIg
# 9998  ZZMJlcWZ1J9piomyl2Sltw  uRwxr1xulZk3g8_eimR6tA  LzVvcVm48zYIcQnwLKt1oA
# 9999  5eFGXwwq7B6R9LezgoCJZQ  IXRk16mfwYskubKioHDzYg  kZ1q0K13tFYG_ZJrVvsJHA
#
#       stars_x                                               text  liked  \
# 0         5.0  This and Suraya are our go to restaurant when ...      1
# 1         5.0  Best pizza I've tasted in south philly....I ha...      1
# 2         5.0  Holy ba-jesus this place is GREAT! Mooooove ov...      1
# 3         4.0  I've been here for drinks at the bar before an...      1
# 4         4.0  Great addition to the neighborhood! My husband...      1
# ...       ...                                                ...    ...
# 9995      5.0  I had a good experience and it was a lot of fu...      1
# 9996      4.0  Came here after hearing so many great reviews ...      1
# 9997      4.0  The esquites is a good way to start your meal ...      1
# 9998      5.0  Ok. Seriously I don't know where to begin! I g...      1
# 9999      4.0  Overall Rating: 3.5/5 (rounded up to 4) \n\nIn...      1
#
#       doc2vec_0  doc2vec_1  doc2vec_2  doc2vec_3  ...  doc2vec_90  doc2vec_91  \
# 0     -0.451069   0.039961   1.145393  -1.439584  ...   -1.377381    1.748691
# 1     -0.311975   0.766700  -0.303642  -1.311117  ...   -0.219193   -0.324556
# 2     -2.587366   0.852212  -1.808332  -3.284638  ...   -0.965245    2.605013
# 3      0.634725   2.300242  -1.474609  -0.844189  ...   -1.077259    1.561410
# 4     -0.010031  -0.833878  -3.206566   0.261463  ...   -1.021978    0.923961
# ...         ...        ...        ...        ...  ...         ...         ...
# 9995   0.246922   0.283172  -0.658029  -0.288496  ...   -0.514799    0.439222
# 9996  -0.391227   1.062975  -0.809399   0.044015  ...   -0.416782    0.008877
# 9997  -0.488460   0.512609  -0.102683  -0.781004  ...   -0.554141    1.082571
# 9998   0.345135  -1.545147  -1.236216   0.350244  ...    1.073642   -0.393033
# 9999   0.865943  -2.826057  -2.367219  -0.241063  ...    0.460806   -0.655561
#
#       doc2vec_92  doc2vec_93  doc2vec_94  doc2vec_95  doc2vec_96  doc2vec_97  \
# 0      -1.017092   -0.620256    1.416039    0.672509   -0.662186   -0.605508
# 1       0.023984   -0.764924    0.503930   -0.840846    0.436587    1.447701
# 2       1.049494   -0.973607    0.048613   -0.816860   -0.450335   -0.254436
# 3       0.601046    0.024337   -0.618392   -1.030566    0.404822    1.013267
# 4      -0.598759    0.381343   -0.377123   -1.242114    1.200541   -0.579291
# ...          ...         ...         ...         ...         ...         ...
# 9995   -0.090009   -0.354539    0.404292    0.468304   -0.219190    0.176248
# 9996   -1.017066   -0.666284   -0.487110    0.852823   -0.199479    0.283766
# 9997    0.499381   -1.086260    0.159616    0.603335    0.084637    0.795217
# 9998    1.016322    1.192494    1.686341   -0.482530    0.347534    1.070352
# 9999    2.674347    1.670577    0.503162    2.405987   -2.828968    0.664960
#
#       doc2vec_98  doc2vec_99
# 0      -0.397329    0.444505
# 1       0.141035    1.260364
# 2       0.703874   -2.108874
# 3       1.445827    0.959639
# 4      -1.025504   -1.072454
# ...          ...         ...
# 9995    0.067341   -0.357425
# 9996    0.822444   -0.365639
# 9997   -0.267860   -1.525839
# 9998   -0.218979    0.286283
# 9999   -0.305311   -0.972402
#
# [10000 rows x 106 columns]

# %%
user_profile_doc2vec =  sample.drop(columns=['review_id', 'business_id', 'stars_x', 'text', 'liked']).groupby("user_id", as_index=False)[sample_expanded.columns].mean()
user_profile_doc2vec
# Out:
#                      user_id  doc2vec_0  doc2vec_1  doc2vec_2  doc2vec_3  \
# 0     -25VzPSb4ox-GdWmKDtshA  -1.301838   0.683539  -1.051339  -1.094017
# 1     -2cKJFFNJ9XVyWBt62mWvA  -0.151490  -0.216041  -0.107470  -0.243526
# 2     -3P0apvgEEM_cCIRyl3bRw   0.236318   2.744531  -0.608267  -1.657934
# 3     -47Rm6DWQxl2skeCl-vFHg   0.370408   0.428403   0.516310  -1.042840
# 4     -6nlh2IbzCbGhWndMLZt1g  -0.490849   1.209373   0.809219   0.774592
# ...                      ...        ...        ...        ...        ...
# 6869  zx2NkJtfSvJhid6rxvYMlg  -0.605965   0.609501   1.637628   0.549139
# 6870  zx43prq7t59Bg5xDOm1t3g  -0.709193   0.686933  -0.610342  -0.181626
# 6871  zxeG7pecqW6SPGrYIP0HSg  -0.860021   0.834991  -0.421162   0.072532
# 6872  zyB2nCLs1x27K-sXLj8aDw  -1.109280   1.809126   0.327575  -1.649184
# 6873  zyNrXvJyYdC34tS6BcCykA  -2.662489   1.146077  -0.288081   0.947977
#
#       doc2vec_4  doc2vec_5  doc2vec_6  doc2vec_7  doc2vec_8  ...  doc2vec_90  \
# 0     -0.747729  -0.833799   0.650213   0.057953   1.348980  ...    0.573487
# 1      1.580797  -0.797302   0.593055   0.974836  -0.153719  ...    1.805690
# 2      3.090559   0.068579  -0.849246   0.799614   0.237397  ...   -0.628696
# 3      0.018001  -0.645075  -0.154592   1.334038  -0.387951  ...   -0.174853
# 4      1.435144   1.191466   0.677854   0.247982  -1.505491  ...    1.042966
# ...         ...        ...        ...        ...        ...  ...         ...
# 6869   1.322350  -0.446108  -1.380047   1.224981  -0.433248  ...   -1.072574
# 6870   0.990744   0.724226   0.863436   0.079055   0.719572  ...    0.343236
# 6871   0.567860  -1.418928   0.307376   0.950814  -0.329542  ...    0.226755
# 6872   0.699434   0.420974   1.010823  -0.129215   0.679385  ...    0.389543
# 6873   0.225818  -0.189019   0.523752   0.547344   1.088710  ...   -1.155591
#
#       doc2vec_91  doc2vec_92  doc2vec_93  doc2vec_94  doc2vec_95  doc2vec_96  \
# 0      -2.113169    0.360323   -0.535257    1.204833   -0.551977   -2.105661
# 1       0.652622    0.294857    0.795383   -1.274903    0.057253    0.071028
# 2       0.827344   -0.515293   -0.476057    0.677622    1.687139   -0.035063
# 3       0.241877   -0.856027   -0.951270   -0.794492   -0.223143    1.088800
# 4       1.719276    0.128132    0.546436    0.307675   -1.225703   -0.480467
# ...          ...         ...         ...         ...         ...         ...
# 6869    0.575207   -0.101791   -0.401478    1.251195   -0.162863    0.925879
# 6870    0.777813   -0.147987   -0.186692    0.813609   -0.552430    0.343865
# 6871    0.058169   -0.579540    0.204547    0.415189   -0.217747   -0.782550
# 6872    0.470620    1.365513   -0.859373    0.764206    0.698052   -0.405975
# 6873    0.520420    0.241350    0.103383   -1.256623   -0.468424    2.229507
#
#       doc2vec_97  doc2vec_98  doc2vec_99
# 0      -0.501908    1.357714   -0.720134
# 1       0.872815   -0.228553    0.310425
# 2       0.322998   -0.489022   -0.299178
# 3       0.232143    0.869431   -0.111912
# 4      -0.763259    0.089684   -0.882564
# ...          ...         ...         ...
# 6869   -0.317275    0.751595    0.509876
# 6870   -0.028431    0.980844   -0.464169
# 6871    0.029245    0.799248   -0.818683
# 6872    1.627416    1.461163    0.564337
# 6873   -0.906250   -0.603862   -0.192047
#
# [6874 rows x 101 columns]

# %%
restaurant_profile_doc2vec =  sample.drop(columns=['review_id', 'user_id', 'stars_x', 'text', 'liked']).groupby("business_id", as_index=False)[sample_expanded.columns].mean()
restaurant_profile_doc2vec
# Out:
#                  business_id  doc2vec_0  doc2vec_1  doc2vec_2  doc2vec_3  \
# 0     -0PN_KFPtbnLQZEeb23XiA  -0.343017  -0.505310  -0.858467   0.003974
# 1     -0TffRSXXIlBYVbb5AwfTg  -0.256850   0.386000  -0.395760  -0.288296
# 2     -0eUa8TsXFFy0FCxHYmrjg  -1.996013  -0.591426  -0.340084   0.765210
# 3     -1B9pP_CrRBJYPICE5WbRA  -0.580241   0.041306  -1.091146  -0.004317
# 4     -2-ih3mE8KPyeKVIzpBfPQ  -0.559072   0.800264  -1.458378  -1.029026
# ...                      ...        ...        ...        ...        ...
# 2708  zujdPV3HT-Y-CKE1GgkMHQ  -0.947553   0.213453   0.003991  -0.664370
# 2709  zvvl3c1FO3O3BZdhusficA  -0.819395  -0.129767  -0.617420  -1.098633
# 2710  zwTmOj4B_OVPMTMYijQiKg  -2.712824  -0.325418   0.666085  -0.555177
# 2711  zwd4dyQ5ovnjVojWfAuhMw  -0.793893   0.197163   0.410260  -1.641406
# 2712  zwgBxmrmPBF6N2uRTUYXrQ  -0.041536   0.949095  -0.217437  -0.653489
#
#       doc2vec_4  doc2vec_5  doc2vec_6  doc2vec_7  doc2vec_8  ...  doc2vec_90  \
# 0      0.787255  -0.108218  -0.586535   0.059905  -0.503976  ...    1.399061
# 1      0.908090   0.097290   0.177546   0.526278   0.072453  ...    0.341356
# 2      1.110209   0.302426  -0.393390   1.676181  -1.171620  ...    0.088121
# 3      0.898353  -0.218667   0.276324   0.688997  -0.240543  ...    0.161978
# 4      1.027816  -1.389903  -0.046550  -0.018216   0.806164  ...    0.521168
# ...         ...        ...        ...        ...        ...  ...         ...
# 2708   0.246650  -0.866719  -0.252758   0.717134  -0.073692  ...    1.202132
# 2709  -0.498430   0.256153   1.815694   2.251440   0.900176  ...   -2.639077
# 2710  -0.564782  -1.448224   0.332883  -0.482389   0.923767  ...    2.069994
# 2711   0.800636   0.292556  -0.536209   0.672725   0.405609  ...   -0.062029
# 2712   0.411336  -0.202927  -0.078407  -0.228351  -0.485353  ...    0.967020
#
#       doc2vec_91  doc2vec_92  doc2vec_93  doc2vec_94  doc2vec_95  doc2vec_96  \
# 0       0.399789    0.378700   -1.964260    1.759055   -0.005532    0.085946
# 1       0.316282    0.211761   -0.403023    0.887313    0.112904   -0.708907
# 2      -0.763345   -0.578279   -0.319888    0.266820   -0.783076    1.112962
# 3       0.000830   -0.179954   -0.247282    0.541362    0.065893   -0.439497
# 4       1.143190   -0.088687    0.298586   -0.121110    0.215365    0.153591
# ...          ...         ...         ...         ...         ...         ...
# 2708    0.740893    0.008193   -0.695996    0.243963   -0.439433    0.138277
# 2709   -1.241327    0.676447    1.896346    0.158675   -0.319389   -0.485694
# 2710   -0.723348    0.643271    0.883189    0.090938    0.331887   -0.136998
# 2711    0.088131   -1.129928   -0.273341    1.933125    1.361800    1.406788
# 2712    0.685904    0.285556    0.907327    0.712410    1.037459   -0.425487
#
#       doc2vec_97  doc2vec_98  doc2vec_99
# 0      -0.410141   -0.270524   -1.346960
# 1       0.217309    0.161457    0.002104
# 2      -0.464288   -0.267040    0.401994
# 3      -0.208325   -0.346133    0.181681
# 4       0.145992   -1.041175   -0.501286
# ...          ...         ...         ...
# 2708   -0.317086    0.559143   -0.189497
# 2709   -0.450734   -0.193166   -0.385535
# 2710    0.153328    1.740309    0.384210
# 2711   -0.432450    1.515419   -0.152973
# 2712   -0.861746   -0.745929   -1.149225
#
# [2713 rows x 101 columns]

# %%
# Recommendations

# select one user
user_id = "-25VzPSb4ox-GdWmKDtshA"
usr_lst = user_profile_doc2vec[user_profile_doc2vec['user_id'] == user_id].drop(columns=['user_id']).values

# removing the restaurants already visited by the user
visited_restaurants = reviews[reviews['user_id'] == user_id]['business_id'].values # including even the ones the user didn't like
new_restaurants = restaurant_profile_doc2vec[-restaurant_profile_doc2vec['business_id'].isin(visited_restaurants)]
new_restaurants.reset_index(drop=True, inplace=True)

# business matrix
bus_matrix = new_restaurants.drop(columns=['business_id']).values

# Compute similarity between user profile and all document topics
similarity_scores = cosine_similarity(usr_lst, bus_matrix)

# Recommend items with highest similarity scores
N = 5
recommended_indices = similarity_scores.argsort()[0][::-1][:N]  # Top N recommendations
new_restaurants.iloc[recommended_indices]["business_id"]
# Out:
# 1394    WP9GAuhvmUhm8MAxMqhgrQ
# 2106    lWedWkinrM5j13pyimbpbA
# 2101    lRbHFOIFuusN2WOR_ypQ_A
# 2090    l8gAoQqqVfphPe9jmIJZ3g
# 2353    rYqmaOIULRouz_1db07OdQ
# Name: business_id, dtype: object

# %%
def recommend(user_id, reviews, user_profile, restaurant_profile, type='user_item', N=5, K=5):
    
    '''
    Provides N recommendations of restaurants to the given user based on three
    different methods explained in the comments

    Inputs:
    user_id - the user the recommendations are aimed at
    reviews - original df with every review
    user_profile - df with the profiles of the users (vectors from LSA/LDA/doc2vec)
    restaurant_profile - df with the profiles of the restaurants (vectors from LSA/LDA/doc2vec)
    type - type of recommendations (user_item, users or items) (default = "user_item")
    N - How many recommendations to output (user_item method) (default = 5)
    K - Number of neighbors to consider (users or items method) (default = 5)
    N_peruser - Number of recommendations per user (only for the users method) (default = 1) [REMOVED]

    Outputs:
    Series of N recommended restaurants (business_id)
    '''

    # Extracting the vector relative to the user and removing the user from the profiles
    usr_lst = user_profile[user_profile['user_id'] == user_id].drop(columns=['user_id']).values
    user_profile = user_profile[user_profile['user_id'] != user_id].reset_index(drop=True)
    
    # Removing the restaurants already visited by the user
    visited_restaurants = reviews[reviews['user_id'] == user_id]['business_id'].values # including even the ones the user didn't like
    new_restaurants = restaurant_profile[-restaurant_profile['business_id'].isin(visited_restaurants)]
    new_restaurants.reset_index(drop=True, inplace=True)

    # Final user and business matrixes in array format
    user_matrix = user_profile.drop(columns=['user_id']).values
    bus_matrix = new_restaurants.drop(columns=['business_id']).values

    if type == 'user_item':
        # Measures the similarity between user and available restaurants
        # Recommends the restaurants that are most similar to the user
        similarity_scores = cosine_similarity(usr_lst, bus_matrix)
        recommended_indices = similarity_scores.argsort()[0][::-1][:N]
        recommendations = new_restaurants.iloc[recommended_indices]["business_id"]
        
    elif type == 'users':
        # Measures the similarity between the user and the other users
        # Recommends the highest rated restaurants by other users that the user has not experienced

        ### Previous version - possibly to delete
        # similarity_scores = cosine_similarity(usr_lst, user_matrix)
        # similar_user_indices = similarity_scores.argsort()[0][::-1][:K]
        # similar_users = user_profile.iloc[similar_user_indices]['user_id']
        # recommendations = reviews[(reviews['user_id'].isin(similar_users)) & (-reviews['business_id'].isin(visited_restaurants))].groupby('user_id').apply(lambda x: x.nlargest(N_peruser, 'stars_x')).reset_index(drop=True)['business_id']    

        ### Properly using the CF approach
        # Similarities between users
        similarity_scores = cosine_similarity(usr_lst, user_matrix)

        # Finding the K most similar users
        similar_user_indices = similarity_scores.argsort()[0][::-1][:K]
        similar_users = user_profile.iloc[similar_user_indices]['user_id']

        # creating a matrix for the similar users
        user_item = reviews[reviews['user_id'].isin(similar_users)][['user_id', 'business_id', 'stars_x']]
        user_item = pd.pivot_table(user_item, index='user_id', columns='business_id', values='stars_x', aggfunc='mean')

        # averaging the ratings for each restaurant [MAYBE TRY AVERAGE WEIGHTED BY SIMILARITY]
        average_ratings = np.mean(user_item, axis=0)

        # removing restaurants already visited
        for i in visited_restaurants:
            try:
                average_ratings.drop(i, inplace=True)
            except:
                continue

        # recommending the top N restaurants
        recommendations = pd.Series(average_ratings.sort_values(ascending=False).head(N).keys())

    elif type == 'items':
        # Measures the similarity between the restaurants
        # Recommends the restaurants that are most similar to the ones the user liked before

        ### Previous version - possibly to delete
        # favorite_business = reviews[reviews['user_id'] == user_id].sort_values('stars_x', ascending=False)['business_id'].head(1)
        # bus_list = restaurant_profile[restaurant_profile['business_id'] == favorite_business].drop(columns=['business_id']).values
        # similarity_scores = cosine_similarity(bus_list, bus_matrix)
        # similar_bus_indices = similarity_scores.argsort()[0][::-1][:K]
        # recommendations = new_restaurants.iloc[similar_bus_indices]['business_id']

        ### Properly using the CF approach
        # getting the user's favorite restaurant
        favorite_business = reviews[reviews['user_id'] == user_id].sort_values('stars_x', ascending=False)['business_id'].head(1).values[0]
        bus_list = restaurant_profile[restaurant_profile['business_id'] == favorite_business].drop(columns=['business_id']).values
        
        # Similarities between users
        similarity_scores = cosine_similarity(bus_list, bus_matrix)

        # Finding the K most similar restaurants
        similar_bus_indices = similarity_scores.argsort()[0][::-1][:K]
        similar_restaurants = new_restaurants.iloc[similar_bus_indices]['business_id']

        # recommending the top N restaurants [WE SHOULD WEIGHT THE RATING BY SIMILARITY OF THE RESTAURANTS THE USER RATED]
        # ASSUMING A RATING OF 5 FOR THESE
        recommendations = similar_restaurants
    
    else:
        raise ValueError("Invalid type. Please choose 'user_item', 'users', or 'items'.")
    
    return recommendations

# %%
recommend('-25VzPSb4ox-GdWmKDtshA', reviews, user_profile_doc2vec, restaurant_profile_doc2vec)
# Out:
# 1394    WP9GAuhvmUhm8MAxMqhgrQ
# 2106    lWedWkinrM5j13pyimbpbA
# 2101    lRbHFOIFuusN2WOR_ypQ_A
# 2090    l8gAoQqqVfphPe9jmIJZ3g
# 2353    rYqmaOIULRouz_1db07OdQ
# Name: business_id, dtype: object

# %%
recommend('-25VzPSb4ox-GdWmKDtshA', reviews, user_profile_doc2vec, restaurant_profile_doc2vec, type='users')
# Out:
# 0    -0TffRSXXIlBYVbb5AwfTg
# 1    A9bqf3aoiQXX9WBswewivg
# 2    mUIBtlWNPD7sz3rGGWQ1RA
# 3    Ay0j65KKb3sOrOFUVWs44g
# 4    B08ELtRljjxnefQ3ayqUZg
# Name: business_id, dtype: object

# %%
recommend('-25VzPSb4ox-GdWmKDtshA', reviews, user_profile, restaurant_profile, type='items')
# Out:
# 1092    AvdhZ3RgY3xJbW-JMACcMg
# 2139    MqAvonk4-cJ-7pW78tR1Rw
# 2485    QgDsoMYcLcVcBQ3UgVay4A
# 3450    aaqm5vJvVj3vyMeGwPqxEw
# 2526    R9VYqhQeGtHpaadx4eK3_A
# Name: business_id, dtype: object
