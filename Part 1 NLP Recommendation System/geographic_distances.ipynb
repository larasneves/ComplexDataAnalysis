# %%
import pandas as pd
from geopy.distance import geodesic

# %%
businesses = pd.read_csv("yelp_academic_dataset_business.csv")

# %%
businesses = businesses[(businesses['city'] == 'Philadelphia') & (businesses['categories'].str.contains('Restaurants', na=False))]
businesses
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 15      MUTTqe8uqyMdBl186RmNeA                       Tuna Bar
# 19      ROeacJQwBeh05Rqg7F6TCg                            BAP
# 28      QdN72BWoyFypdGJhhI5r7g                        Bar One
# 31      Mjboz24M9NlBeiOJKLEd_Q               DeSandro on Main
# ...                        ...                            ...
# 150287  VZbkSeZtFynEascotq7ExA            Ali Baba Magic Food
# 150298  gPr1io7ks0Eo3FDsnDTYfg                      Tata Cafe
# 150306  wVxXRFf10zTTAs11nr4xeA                   PrimoHoagies
# 150319  8n93L-ilMAsvwUatarykSg                    Kitchen Gia
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
#
#                     address          city state postal_code   latitude  \
# 3               935 Race St  Philadelphia    PA       19107  39.955505
# 15              205 Race St  Philadelphia    PA       19106  39.953949
# ...

# %%
# straight line distance in km
def geopy_distance(lat1, lon1, restaurant):

    coords_1 = (lat1, lon1)
    coords_2 = (float(businesses[businesses['business_id'] == restaurant]['latitude']), float(businesses[businesses['business_id'] == restaurant]['longitude']))
    
    return geodesic(coords_1, coords_2).kilometers

# %%
geopy_distance(40, -80, 'WnT9NIzQgLlILjPT0kEcsQ')
# Out:
# 413.62346515010694
